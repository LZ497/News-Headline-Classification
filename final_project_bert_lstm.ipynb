# %%
import pandas as pd
import numpy as np
import sklearn
import matplotlib.pyplot as plt
import seaborn as sns
import re
import os
import glob
import pylab as pl
from sklearn.cluster import KMeans
from wordcloud import WordCloud, STOPWORDS
from nltk.stem import WordNetLemmatizer, PorterStemmer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.tokenize import word_tokenize
from pandas import DataFrame
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, plot_confusion_matrix
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn import tree 
from sklearn import preprocessing
import plotly.express as px
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import Perceptron
from sklearn.svm import SVC, LinearSVC
from sklearn.naive_bayes import MultinomialNB
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report, confusion_matrix,roc_auc_score,roc_curve
import matplotlib.pyplot as plt

# %%
import nltk
nltk.download('wordnet')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# # Part 1: Text cleaning

# %%
News_DF=pd.read_csv('News_Headline.csv', error_bad_lines=False, encoding='latin-1')

# %%
News_DF = News_DF.drop(columns=['Unnamed: 5','Unnamed: 6','Unnamed: 7','Unnamed: 8','Unnamed: 9','Unnamed: 10','Unnamed: 11'])

# %% [markdown]
# ## split the datasets

# %%
from sklearn.model_selection import train_test_split
News_DF['cata'] = pd.factorize(News_DF['category'])[0] 
Xtrain,Xtest ,ytrain,ytest = train_test_split(News_DF['headline'], News_DF['cata'], random_state = 2020, test_size = 0.2)

# %% [markdown]
# # Part 7: BERT

# %%
from transformers import DistilBertTokenizerFast
from tqdm import tqdm
import torch
from transformers import DistilBertForSequenceClassification, \
  AdamW, get_linear_schedule_with_warmup
from datasets import load_metric

batch_size = 15
epochs = 2
lr_init = 1e-5
max_len = 256
warmup_steps = 3


K = 9



##Create batched inputs using Huggingface's DistilBERT tokenizer
tokenizer = DistilBertTokenizerFast.from_pretrained('distilbert-base-cased')
def batch_data(data, labels, bsize):
    batches = []
    sentences = data.tolist()
    labels = labels.tolist()
    for i in range(0, len(sentences), bsize):
        s = sentences[i: i + bsize]
        Y = labels[i: i + bsize]
        X = tokenizer.batch_encode_plus(
            s, max_length=max_len, padding='longest', truncation=True,
            return_attention_mask=True, return_token_type_ids=False)
        batches.append((X, Y, s))
    return batches


train_batches = batch_data(Xtrain, ytrain, bsize=batch_size)
test_batches = batch_data(Xtest, ytest, bsize=batch_size)

model = DistilBertForSequenceClassification.from_pretrained(
    'distilbert-base-cased', 
    num_labels=K, 
    output_hidden_states=True)

if torch.cuda.is_available():
    device = torch.device('cuda:0') # GPU
else:
    device = torch.device('cpu') # CPU
model.to(device)


optimizer = AdamW(model.parameters(), lr=lr_init)
lr = get_linear_schedule_with_warmup(
    optimizer, num_warmup_steps=warmup_steps, 
    num_training_steps=len(train_batches))


def runner(batches, desc: str, train=True):
    
    grad_mode = torch.enable_grad if train else torch.no_grad
    preds = []
    
    if train:
        model.train()
    else:
        model.eval()
    
    for epoch in range(epochs if train else 1):
        
        acc = load_metric("accuracy",keep_in_memory=True)
        f1 = load_metric("f1",keep_in_memory=True)
        precision= load_metric("precision",keep_in_memory=True)
        recall= load_metric("recall",keep_in_memory=True)

        cumloss = 0.0
        embeds = []
        
        with tqdm(total=len(batches)) as bar:

            for i, batch in enumerate(batches):
                X, Y, _ = batch
                inputs = torch.tensor(X['input_ids'], device=device)
                attmsk = torch.tensor(X['attention_mask'], device=device)
                labels = torch.tensor(Y, device=device)
                batch = {'input_ids': inputs,
                         'attention_mask': attmsk,
                         'labels': labels}
                with grad_mode():
                    outputs = model(**batch)
                    embeds.append(outputs[-1][1][:, 0, :].squeeze().detach().cpu())
                    loss = outputs.loss
                    if train:
                        loss.backward()
                        optimizer.step()
                        lr.step()
                        optimizer.zero_grad()
                    logits = outputs.logits
                    Yhat = torch.argmax(logits, dim=-1)
                    preds.append(Yhat)
                    cumloss += loss.clone().detach().cpu().item()
                    acc.add_batch(predictions=Yhat, references=Y)
                    f1.add_batch(predictions=Yhat, references=Y)
                    precision.add_batch(predictions=Yhat, references=Y)
                    recall.add_batch(predictions=Yhat, references=Y)

                bar.update(1)
            bar.set_description('epoch: %s, %s loss: %.5f, f1-score: %.5f, accuracy: %.5f, precision: %.5f, recall: %.5f' %
                                (epoch + 1, desc,
                                 cumloss / (i + 1),                
                                 f1.compute(average="macro")['f1'],
                                 acc.compute()['accuracy'],
                               precision.compute(average="macro")['precision'],
                               recall.compute(average="macro")['recall']))
                
    embeds = torch.cat(embeds, dim=0)
    return preds, embeds
# Out:
# Some weights of the model checkpoint at distilbert-base-cased were not used when initializing DistilBertForSequenceClassification: ['vocab_projector.weight', 'vocab_layer_norm.bias', 'vocab_transform.weight', 'vocab_transform.bias', 'vocab_layer_norm.weight', 'vocab_projector.bias']
# - This IS expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-cased and are newly initialized: ['classifier.bias', 'pre_classifier.bias', 'pre_classifier.weight', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
runner(train_batches, 'train')
# Out:
# Downloading:   0%|          | 0.00/1.42k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.07k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.10k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.10k [00:00<?, ?B/s]
# epoch: 1, train loss: 0.88823, f1-score: 0.72398, accuracy: 0.72437, precision: 0.72450, recall: 0.72432: 100%|██████████| 2396/2396 [05:23<00:00,  7.40it/s]
# epoch: 2, train loss: 0.62453, f1-score: 0.80974, accuracy: 0.80984, precision: 0.81017, recall: 0.80979: 100%|██████████| 2396/2396 [05:22<00:00,  7.43it/s]
# ([tensor([8, 5, 8, 8, 3, 5, 8, 5, 3, 8, 8, 8, 8, 8, 8], device='cuda:0'),
#   tensor([8, 3, 5, 8, 8, 8, 8, 8, 3, 8, 8, 3, 8, 3, 8], device='cuda:0'),
#   tensor([8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 5, 8, 5, 8], device='cuda:0'),
#   tensor([8, 8, 8, 8, 3, 8, 8, 8, 8, 8, 8, 5, 8, 8, 8], device='cuda:0'),
#   tensor([8, 8, 8, 8, 8, 3, 8, 3, 8, 8, 8, 8, 8, 8, 5], device='cuda:0'),
#   tensor([8, 8, 8, 8, 8, 3, 8, 8, 8, 8, 3, 5, 3, 8, 8], device='cuda:0'),
#   tensor([8, 5, 5, 8, 5, 8, 8, 8, 8, 8, 3, 8, 8, 8, 8], device='cuda:0'),
#   tensor([1, 5, 3, 8, 8, 8, 8, 1, 8, 5, 7, 1, 5, 8, 8], device='cuda:0'),
#   tensor([8, 5, 8, 8, 8, 3, 8, 8, 1, 5, 5, 8, 8, 5, 8], device='cuda:0'),
#   tensor([8, 8, 8, 8, 8, 7, 1, 8, 3, 8, 8, 8, 7, 7, 8], device='cuda:0'),
#   tensor([5, 3, 5, 1, 1, 8, 8, 3, 8, 8, 8, 8, 8, 8, 8], device='cuda:0'),
#   tensor([8, 8, 8, 5, 8, 8, 8, 8, 8, 8, 3, 7, 5, 1, 1], device='cuda:0'),
#   tensor([1, 8, 8, 8, 5, 8, 8, 8, 8, 8, 5, 8, 8, 5, 3], device='cuda:0'),
#   tensor([8, 5, 8, 1, 5, 8, 7, 1, 8, 8, 1, 8, 7, 8, 8], device='cuda:0'),
#   tensor([8, 5, 8, 7, 8, 3, 8, 1, 8, 5, 3, 8, 7, 1, 1], device='cuda:0'),
#   tensor([8, 1, 8, 1, 1, 5, 1, 1, 5, 5, 7, 8, 8, 7, 5], device='cuda:0'),
#   tensor([8, 8, 8, 8, 5, 5, 1, 1, 8, 8, 1, 8, 1, 8, 3], device='cuda:0'),
#   tensor([5, 1, 8, 8, 7, 1, 1, 8, 8, 8, 8, 8, 8, 1, 5], device='cuda:0'),
#   tensor([8, 1, 8, 8, 8, 8, 7, 1, 8, 8, 1, 7, 5, 1, 8], device='cuda:0'),
#   tensor([8, 8, 8, 1, 1, 8, 8, 1, 8, 1, 8, 1, 8, 1, 8], device='cuda:0'),
#   tensor([8, 8, 1, 8, 8, 8, 8, 1, 1, 8, 8, 7, 1, 1, 8], device='cuda:0'),
#   tensor([8, 7, 8, 1, 1, 1, 1, 8, 8, 3, 5, 1, 7, 5, 8], device='cuda:0'),
#   tensor([8, 7, 7, 8, 1, 8, 1, 8, 5, 8, 8, 8, 1, 8, 8], device='cuda:0'),
#   tensor([7, 1, 5, 8, 1, 8, 8, 1, 1, 1, 1, 8, 1, 7, 1], device='cuda:0'),
#   tensor([1, 8, 1, 8, 8, 8, 1, 8, 3, 1, 8, 8, 1, 1, 7], device='cuda:0'),
#   tensor([8, 8, 8, 1, 1, 8, 1, 1, 1, 1, 8, 8, 1, 1, 8], device='cuda:0'),
#   tensor([8, 8, 1, 1, 1, 8, 8, 1, 1, 1, 8, 1, 8, 8, 1], device='cuda:0'),
#   tensor([1, 1, 8, 8, 8, 8, 8, 8, 7, 1, 8, 1, 8, 7, 7], device='cuda:0'),
#   tensor([8, 8, 8, 1, 1, 8, 1, 1, 1, 1, 5, 1, 7, 8, 8], device='cuda:0'),
#   tensor([7, 8, 1, 1, 8, 7, 1, 8, 7, 8, 8, 1, 1, 8, 1], device='cuda:0'),
#   tensor([8, 1, 1, 1, 8, 8, 7, 1, 7, 8, 1, 1, 1, 8, 8], device='cuda:0'),
#   tensor([8, 8, 8, 7, 8, 7, 7, 8, 1, 8, 1, 1, 7, 1, 8], device='cuda:0'),
#   tensor([8, 8, 1, 8, 8, 7, 8, 8, 8, 8, 8, 8, 8, 1, 8], device='cuda:0'),
#   tensor([8, 8, 7, 8, 8, 3, 8, 8, 4, 8, 1, 8, 8, 8, 8], device='cuda:0'),
#   tensor([8, 8, 1, 8, 1, 8, 1, 8, 8, 8, 8, 1, 1, 7, 8], device='cuda:0'),
#   tensor([5, 7, 8, 8, 8, 1, 7, 5, 8, 1, 1, 8, 8, 1, 8], device='cuda:0'),
#   tensor([8, 1, 1, 8, 1, 3, 1, 1, 1, 1, 8, 8, 8, 8, 5], device='cuda:0'),
#   tensor([8, 8, 8, 1, 8, 4, 1, 1, 7, 8, 8, 1, 1, 3, 1], device='cuda:0'),
#   tensor([7, 8, 1, 4, 8, 1, 3, 1, 1, 7, 8, 8, 8, 7, 8], device='cuda:0'),
#   tensor([7, 4, 1, 1, 1, 1, 1, 1, 8, 8, 1, 3, 1, 1, 1], device='cuda:0'),
#   tensor([1, 8, 4, 8, 1, 1, 1, 1, 8, 4, 3, 1, 8, 3, 8], device='cuda:0'),
#   tensor([1, 8, 1, 3, 1, 8, 7, 3, 4, 4, 1, 1, 8, 7, 4], device='cuda:0'),
#   tensor([1, 1, 1, 1, 3, 8, 8, 4, 4, 3, 1, 7, 7, 1, 7], device='cuda:0'),
#   tensor([3, 8, 3, 3, 4, 1, 7, 7, 1, 3, 7, 1, 3, 8, 4], device='cuda:0'),
#   tensor([1, 3, 3, 3, 1, 1, 1, 7, 7, 7, 1, 8, 3, 8, 1], device='cuda:0'),
#   tensor([3, 4, 3, 7, 7, 1, 1, 8, 1, 1, 3, 4, 3, 1, 3], device='cuda:0'),
#   tensor([1, 3, 7, 3, 1, 1, 1, 1, 4, 1, 3, 1, 7, 3, 1], device='cuda:0'),
#   tensor([1, 1, 1, 3, 4, 7, 8, 1, 7, 1, 3, 7, 1, 7, 7], device='cuda:0'),
#   tensor([3, 3, 7, 1, 3, 3, 1, 1, 5, 3, 7, 3, 1, 1, 3], device='cuda:0'),
#   tensor([1, 4, 4, 1, 1, 3, 3, 7, 1, 1, 1, 3, 1, 7, 3], device='cuda:0'),
#   tensor([1, 1, 7, 7, 3, 1, 4, 3, 1, 3, 1, 3, 3, 7, 3], device='cuda:0'),
#   tensor([4, 4, 3, 1, 1, 1, 3, 3, 1, 3, 1, 1, 7, 1, 7], device='cuda:0'),
#   tensor([3, 3, 3, 1, 3, 3, 3, 3, 7, 3, 4, 3, 3, 7, 1], device='cuda:0'),
#   tensor([1, 3, 3, 7, 1, 3, 1, 3, 3, 3, 3, 3, 7, 3, 1], device='cuda:0'),
#   tensor([3, 3, 3, 3, 4, 3, 3, 3, 1, 1, 3, 3, 3, 3, 4], device='cuda:0'),
#   tensor([3, 3, 3, 3, 3, 1, 4, 4, 1, 4, 3, 3, 6, 7, 1], device='cuda:0'),
#   tensor([4, 7, 7, 3, 7, 1, 3, 1, 3, 3, 3, 3, 7, 3, 3], device='cuda:0'),
#   tensor([3, 3, 3, 1, 3, 3, 3, 4, 1, 4, 7, 4, 7, 3, 7], device='cuda:0'),
#   tensor([3, 3, 4, 1, 3, 3, 3, 3, 3, 3, 3, 3, 4, 3, 4], device='cuda:0'),
#   tensor([3, 4, 6, 8, 4, 3, 4, 3, 7, 3, 3, 4, 3, 3, 3], device='cuda:0'),
#   tensor([7, 6, 3, 1, 3, 3, 6, 3, 3, 4, 3, 4, 3, 7, 3], device='cuda:0'),
#   tensor([3, 7, 4, 3, 1, 3, 3, 4, 6, 3, 1, 4, 3, 3, 3], device='cuda:0'),
#   tensor([6, 3, 3, 1, 3, 7, 4, 3, 3, 7, 4, 3, 5, 4, 3], device='cuda:0'),
#   tensor([3, 7, 6, 3, 7, 3, 3, 3, 3, 3, 8, 3, 3, 7, 6], device='cuda:0'),
#   tensor([4, 3, 3, 8, 5, 8, 4, 7, 3, 3, 3, 3, 3, 8, 4], device='cuda:0'),
#   tensor([4, 3, 3, 3, 6, 3, 8, 8, 6, 3, 3, 3, 3, 3, 4], device='cuda:0'),
#   tensor([8, 3, 3, 8, 3, 4, 6, 4, 3, 4, 6, 3, 3, 4, 7], device='cuda:0'),
#   tensor([6, 4, 4, 3, 3, 4, 4, 6, 3, 3, 4, 4, 3, 3, 3], device='cuda:0'),
#   tensor([3, 3, 4, 8, 3, 6, 8, 8, 3, 8, 6, 6, 3, 3, 0], device='cuda:0'),
#   tensor([6, 4, 3, 3, 3, 4, 1, 6, 3, 7, 1, 3, 1, 6, 3], device='cuda:0'),
#   tensor([8, 4, 7, 6, 3, 3, 4, 3, 4, 4, 8, 0, 3, 4, 8], device='cuda:0'),
#   tensor([4, 8, 4, 7, 3, 3, 3, 4, 8, 6, 8, 4, 7, 0, 3], device='cuda:0'),
#   tensor([6, 4, 4, 6, 4, 4, 4, 6, 7, 5, 8, 8, 4, 1, 4], device='cuda:0'),
#   tensor([3, 4, 4, 6, 7, 4, 4, 3, 3, 3, 6, 4, 6, 3, 4], device='cuda:0'),
#   tensor([4, 6, 8, 4, 4, 8, 4, 0, 8, 4, 8, 3, 6, 3, 3], device='cuda:0'),
#   tensor([3, 4, 4, 4, 3, 0, 8, 8, 4, 1, 4, 4, 4, 4, 8], device='cuda:0'),
#   tensor([3, 4, 1, 5, 4, 1, 4, 5, 3, 1, 8, 4, 4, 4, 4], device='cuda:0'),
#   tensor([4, 4, 4, 4, 4, 4, 8, 4, 1, 6, 4, 3, 5, 4, 8], device='cuda:0'),
#   tensor([4, 4, 4, 4, 3, 3, 3, 4, 4, 3, 1, 1, 3, 3, 6], device='cuda:0'),
#   tensor([3, 3, 3, 5, 4, 1, 3, 4, 4, 1, 4, 0, 4, 5, 8], device='cuda:0'),
#   tensor([1, 0, 4, 4, 3, 4, 4, 8, 6, 1, 3, 8, 8, 3, 3], device='cuda:0'),
#   tensor([4, 0, 0, 8, 3, 3, 7, 4, 0, 4, 3, 4, 8, 4, 8], device='cuda:0'),
#   tensor([4, 3, 3, 4, 6, 4, 0, 8, 8, 0, 8, 3, 4, 4, 2], device='cuda:0'),
#   tensor([3, 4, 8, 3, 4, 4, 4, 3, 4, 4, 8, 5, 8, 4, 3], device='cuda:0'),
#   tensor([4, 4, 3, 0, 4, 4, 5, 4, 3, 4, 3, 0, 4, 4, 1], device='cuda:0'),
#   tensor([3, 6, 4, 8, 0, 5, 8, 0, 6, 3, 3, 6, 5, 3, 8], device='cuda:0'),
#   tensor([4, 6, 0, 4, 3, 4, 8, 4, 3, 4, 4, 5, 6, 6, 8], device='cuda:0'),
#   tensor([3, 4, 0, 0, 0, 5, 4, 8, 4, 4, 8, 3, 0, 3, 0], device='cuda:0'),
#   tensor([4, 3, 8, 0, 4, 4, 4, 1, 0, 4, 3, 1, 0, 3, 3], device='cuda:0'),
#   tensor([4, 0, 0, 4, 3, 8, 4, 8, 0, 8, 6, 4, 7, 3, 4], device='cuda:0'),
#   tensor([5, 3, 0, 0, 0, 5, 5, 4, 3, 6, 0, 4, 0, 5, 3], device='cuda:0'),
#   tensor([0, 4, 7, 3, 4, 1, 2, 5, 4, 4, 8, 4, 4, 5, 8], device='cuda:0'),
#   tensor([4, 0, 4, 3, 0, 2, 3, 8, 3, 0, 5, 0, 1, 5, 1], device='cuda:0'),
#   tensor([4, 0, 4, 3, 5, 4, 5, 4, 4, 5, 0, 5, 4, 8, 0], device='cuda:0'),
#   tensor([8, 3, 4, 5, 4, 3, 4, 4, 5, 3, 6, 2, 5, 5, 0], device='cuda:0'),
#   tensor([8, 3, 5, 3, 4, 2, 4, 5, 4, 8, 4, 2, 5, 0, 8], device='cuda:0'),
#   tensor([4, 2, 3, 3, 4, 0, 8, 5, 4, 4, 1, 0, 0, 2, 6], device='cuda:0'),
#   tensor([0, 4, 0, 4, 5, 5, 3, 7, 2, 0, 7, 1, 2, 0, 0], device='cuda:0'),
#   tensor([1, 4, 7, 5, 4, 0, 0, 3, 2, 8, 0, 6, 7, 1, 3], device='cuda:0'),
#   tensor([2, 0, 5, 0, 4, 4, 3, 3, 4, 4, 3, 8, 0, 2, 5], device='cuda:0'),
#   tensor([5, 5, 3, 4, 4, 1, 6, 0, 0, 1, 3, 8, 1, 2, 1], device='cuda:0'),
#   tensor([1, 4, 8, 3, 3, 5, 4, 0, 8, 7, 4, 2, 0, 3, 1], device='cuda:0'),
#   tensor([1, 3, 0, 8, 4, 0, 0, 8, 2, 0, 2, 7, 6, 3, 5], device='cuda:0'),
#   tensor([8, 6, 3, 6, 4, 3, 3, 8, 3, 8, 6, 2, 3, 5, 3], device='cuda:0'),
#   tensor([4, 3, 8, 3, 5, 4, 6, 8, 1, 6, 1, 6, 5, 5, 8], device='cuda:0'),
#   tensor([8, 8, 3, 3, 6, 3, 2, 8, 1, 2, 0, 3, 1, 0, 0], device='cuda:0'),
#   tensor([8, 2, 5, 3, 7, 8, 5, 2, 6, 8, 4, 3, 8, 1, 3], device='cuda:0'),
#   tensor([4, 8, 3, 3, 8, 3, 5, 8, 2, 4, 0, 6, 8, 0, 8], device='cuda:0'),
#   tensor([6, 6, 3, 8, 0, 6, 3, 5, 8, 2, 8, 0, 3, 5, 5], device='cuda:0'),
#   tensor([3, 8, 5, 8, 5, 6, 0, 6, 2, 8, 3, 5, 2, 8, 3], device='cuda:0'),
#   tensor([2, 2, 3, 6, 5, 6, 6, 3, 5, 5, 2, 8, 5, 6, 0], device='cuda:0'),
#   tensor([6, 6, 5, 2, 4, 2, 3, 2, 6, 2, 5, 5, 2, 4, 1], device='cuda:0'),
#   tensor([2, 5, 5, 4, 4, 6, 2, 3, 5, 0, 4, 0, 8, 1, 8], device='cuda:0'),
#   tensor([1, 8, 8, 5, 6, 8, 1, 3, 0, 8, 5, 4, 0, 5, 3], device='cuda:0'),
#   tensor([2, 6, 8, 0, 6, 7, 4, 6, 0, 6, 3, 4, 6, 6, 8], device='cuda:0'),
#   tensor([5, 3, 8, 6, 0, 1, 8, 1, 6, 3, 5, 8, 6, 8, 3], device='cuda:0'),
#   tensor([6, 4, 5, 4, 5, 0, 1, 6, 8, 4, 3, 6, 6, 5, 8], device='cuda:0'),
#   tensor([1, 8, 3, 0, 6, 3, 6, 0, 5, 0, 4, 2, 3, 0, 6], device='cuda:0'),
#   tensor([6, 3, 5, 0, 5, 8, 4, 5, 6, 6, 4, 0, 6, 0, 0], device='cuda:0'),
#   tensor([1, 1, 8, 6, 4, 6, 0, 0, 6, 6, 5, 5, 0, 1, 6], device='cuda:0'),
#   tensor([3, 5, 4, 5, 8, 4, 5, 5, 6, 6, 8, 0, 4, 8, 6], device='cuda:0'),
#   tensor([4, 5, 6, 3, 6, 2, 7, 4, 8, 3, 5, 0, 5, 6, 4], device='cuda:0'),
#   tensor([2, 6, 6, 6, 0, 1, 6, 6, 5, 6, 1, 5, 7, 5, 4], device='cuda:0'),
#   tensor([4, 5, 8, 3, 3, 0, 1, 3, 0, 5, 3, 3, 0, 4, 6], device='cuda:0'),
#   tensor([1, 8, 5, 2, 7, 6, 5, 5, 1, 5, 5, 2, 8, 3, 5], device='cuda:0'),
#   tensor([8, 1, 3, 5, 7, 0, 5, 5, 2, 0, 8, 7, 8, 4, 4], device='cuda:0'),
#   tensor([8, 5, 6, 6, 5, 7, 8, 4, 4, 1, 0, 4, 5, 5, 7], device='cuda:0'),
#   tensor([3, 0, 1, 4, 5, 4, 5, 1, 1, 6, 1, 1, 3, 5, 1], device='cuda:0'),
#   tensor([2, 5, 5, 7, 5, 4, 5, 5, 7, 3, 4, 6, 1, 3, 1], device='cuda:0'),
#   tensor([1, 5, 5, 1, 8, 7, 0, 5, 5, 3, 1, 5, 0, 4, 3], device='cuda:0'),
#   tensor([6, 1, 4, 5, 0, 5, 2, 8, 0, 5, 7, 0, 6, 1, 7], device='cuda:0'),
#   tensor([8, 0, 3, 8, 3, 5, 5, 2, 1, 2, 4, 1, 5, 8, 4], device='cuda:0'),
#   tensor([6, 5, 1, 5, 1, 6, 4, 7, 0, 5, 0, 4, 5, 0, 4], device='cuda:0'),
#   tensor([7, 1, 4, 7, 0, 3, 0, 5, 8, 5, 1, 5, 6, 3, 3], device='cuda:0'),
#   tensor([4, 7, 1, 1, 5, 4, 0, 4, 0, 7, 3, 7, 1, 7, 4], device='cuda:0'),
#   tensor([7, 5, 7, 8, 7, 8, 0, 3, 0, 0, 7, 5, 0, 7, 8], device='cuda:0'),
#   tensor([8, 2, 5, 3, 3, 5, 3, 5, 5, 0, 7, 1, 7, 5, 7], device='cuda:0'),
#   tensor([3, 3, 0, 8, 8, 7, 4, 0, 1, 3, 7, 5, 8, 2, 0], device='cuda:0'),
#   tensor([1, 1, 3, 0, 2, 1, 0, 5, 4, 5, 7, 5, 7, 5, 3], device='cuda:0'),
#   tensor([5, 8, 5, 8, 0, 7, 0, 2, 6, 8, 7, 1, 0, 2, 3], device='cuda:0'),
#   tensor([8, 8, 7, 0, 0, 2, 7, 7, 8, 2, 6, 1, 8, 2, 3], device='cuda:0'),
#   tensor([6, 2, 7, 3, 1, 4, 4, 4, 1, 8, 7, 7, 4, 5, 3], device='cuda:0'),
#   tensor([2, 3, 1, 5, 0, 1, 2, 4, 0, 7, 5, 0, 6, 4, 7], device='cuda:0'),
#   tensor([2, 1, 1, 7, 8, 8, 4, 4, 0, 1, 8, 2, 2, 5, 4], device='cuda:0'),
#   tensor([1, 8, 3, 2, 0, 4, 8, 0, 0, 1, 1, 3, 3, 8, 1], device='cuda:0'),
#   tensor([2, 4, 6, 7, 1, 1, 3, 0, 4, 4, 3, 6, 8, 3, 0], device='cuda:0'),
#   tensor([3, 5, 7, 2, 6, 6, 3, 3, 5, 3, 0, 7, 7, 3, 2], device='cuda:0'),
#   tensor([3, 0, 6, 8, 2, 0, 4, 7, 2, 1, 1, 6, 5, 8, 8], device='cuda:0'),
#   tensor([1, 4, 1, 0, 6, 0, 0, 5, 0, 0, 0, 5, 5, 0, 8], device='cuda:0'),
#   tensor([0, 1, 6, 4, 6, 5, 1, 5, 3, 1, 6, 7, 1, 6, 0], device='cuda:0'),
#   tensor([1, 3, 4, 8, 3, 7, 1, 3, 0, 7, 5, 3, 2, 4, 1], device='cuda:0'),
#   tensor([1, 1, 1, 1, 5, 1, 7, 0, 7, 1, 5, 0, 1, 7, 5], device='cuda:0'),
#   tensor([4, 5, 5, 0, 2, 4, 5, 3, 5, 8, 0, 1, 0, 3, 6], device='cuda:0'),
#   tensor([0, 8, 4, 3, 8, 2, 3, 6, 8, 1, 6, 0, 0, 8, 8], device='cuda:0'),
#   tensor([2, 7, 7, 5, 5, 3, 6, 1, 3, 8, 5, 8, 7, 0, 2], device='cuda:0'),
#   tensor([1, 3, 5, 0, 1, 5, 8, 4, 3, 6, 5, 4, 2, 0, 1], device='cuda:0'),
#   tensor([6, 6, 3, 0, 5, 6, 8, 5, 5, 6, 6, 3, 2, 6, 7], device='cuda:0'),
#   tensor([1, 2, 7, 4, 2, 8, 5, 8, 8, 6, 3, 0, 0, 4, 1], device='cuda:0'),
#   tensor([6, 6, 5, 6, 5, 0, 6, 4, 5, 8, 5, 4, 8, 7, 4], device='cuda:0'),
#   tensor([4, 3, 8, 0, 4, 6, 1, 4, 6, 8, 3, 5, 4, 5, 6], device='cuda:0'),
#   tensor([0, 0, 5, 4, 4, 6, 0, 8, 7, 0, 6, 0, 4, 6, 8], device='cuda:0'),
#   tensor([7, 7, 6, 5, 5, 6, 0, 0, 7, 0, 6, 0, 8, 6, 4], device='cuda:0'),
#   tensor([1, 5, 0, 7, 6, 8, 4, 8, 5, 5, 4, 2, 5, 2, 0], device='cuda:0'),
#   tensor([3, 6, 1, 1, 5, 6, 5, 8, 8, 1, 2, 6, 8, 7, 5], device='cuda:0'),
#   tensor([2, 7, 8, 3, 0, 5, 0, 4, 5, 3, 5, 5, 1, 6, 0], device='cuda:0'),
#   tensor([1, 4, 2, 5, 0, 1, 0, 4, 5, 7, 6, 8, 5, 5, 6], device='cuda:0'),
#   tensor([3, 8, 1, 0, 6, 8, 3, 7, 7, 6, 1, 5, 5, 6, 1], device='cuda:0'),
#   tensor([8, 4, 6, 5, 8, 7, 6, 1, 5, 1, 4, 8, 5, 4, 4], device='cuda:0'),
#   tensor([3, 4, 5, 4, 0, 8, 5, 4, 4, 5, 8, 0, 8, 8, 5], device='cuda:0'),
#   tensor([3, 1, 4, 5, 6, 3, 4, 7, 6, 2, 3, 0, 6, 1, 2], device='cuda:0'),
#   tensor([8, 8, 8, 1, 5, 5, 7, 7, 8, 1, 0, 3, 3, 8, 3], device='cuda:0'),
#   tensor([8, 6, 2, 6, 0, 3, 5, 4, 2, 3, 4, 3, 8, 5, 1], device='cuda:0'),
#   tensor([3, 0, 3, 3, 7, 5, 6, 8, 3, 3, 5, 3, 6, 8, 8], device='cuda:0'),
#   tensor([5, 8, 4, 4, 0, 3, 3, 4, 0, 0, 6, 8, 2, 3, 0], device='cuda:0'),
#   tensor([4, 3, 8, 7, 8, 6, 3, 3, 8, 7, 8, 8, 5, 1, 8], device='cuda:0'),
#   tensor([0, 6, 5, 5, 0, 0, 4, 6, 5, 7, 2, 6, 7, 4, 7], device='cuda:0'),
#   tensor([3, 3, 0, 0, 3, 5, 5, 0, 8, 7, 5, 8, 7, 7, 4], device='cuda:0'),
#   tensor([4, 7, 0, 4, 5, 4, 5, 1, 0, 5, 8, 6, 5, 6, 8], device='cuda:0'),
#   tensor([4, 0, 4, 0, 7, 2, 5, 4, 1, 8, 0, 8, 8, 8, 4], device='cuda:0'),
#   tensor([4, 5, 5, 1, 5, 8, 3, 4, 6, 4, 0, 4, 8, 2, 5], device='cuda:0'),
#   tensor([5, 3, 4, 3, 2, 3, 2, 5, 7, 5, 5, 6, 2, 2, 0], device='cuda:0'),
#   tensor([4, 8, 5, 7, 5, 0, 4, 4, 5, 5, 0, 1, 3, 4, 5], device='cuda:0'),
#   tensor([8, 2, 8, 6, 8, 6, 1, 7, 2, 1, 0, 3, 5, 3, 8], device='cuda:0'),
#   tensor([4, 7, 3, 1, 1, 8, 4, 6, 1, 8, 5, 8, 8, 1, 4], device='cuda:0'),
#   tensor([7, 7, 6, 8, 6, 6, 4, 3, 1, 2, 7, 0, 5, 6, 4], device='cuda:0'),
#   tensor([7, 1, 6, 6, 6, 3, 6, 1, 4, 6, 1, 8, 5, 4, 0], device='cuda:0'),
#   tensor([1, 1, 4, 8, 5, 3, 6, 6, 0, 7, 5, 7, 6, 8, 7], device='cuda:0'),
#   tensor([5, 6, 6, 4, 4, 6, 2, 8, 7, 4, 0, 0, 0, 4, 4], device='cuda:0'),
#   tensor([6, 1, 0, 2, 8, 2, 3, 2, 3, 6, 6, 0, 3, 4, 5], device='cuda:0'),
#   tensor([1, 6, 1, 5, 8, 1, 1, 6, 7, 6, 3, 4, 2, 8, 6], device='cuda:0'),
#   tensor([4, 3, 5, 8, 4, 3, 6, 3, 1, 3, 1, 7, 8, 0, 0], device='cuda:0'),
#   tensor([6, 6, 0, 1, 6, 4, 6, 6, 1, 3, 7, 4, 3, 3, 5], device='cuda:0'),
#   tensor([0, 6, 6, 3, 3, 4, 1, 8, 1, 3, 4, 3, 4, 0, 0], device='cuda:0'),
#   tensor([7, 8, 3, 6, 1, 3, 6, 7, 0, 8, 6, 3, 6, 2, 6], device='cuda:0'),
#   tensor([4, 4, 3, 1, 7, 0, 1, 2, 4, 4, 5, 4, 6, 6, 2], device='cuda:0'),
#   tensor([4, 4, 5, 7, 0, 4, 7, 4, 3, 1, 5, 6, 2, 0, 4], device='cuda:0'),
#   tensor([6, 7, 1, 3, 2, 5, 8, 0, 3, 1, 3, 8, 1, 3, 7], device='cuda:0'),
#   tensor([0, 1, 1, 6, 4, 3, 4, 4, 6, 2, 3, 3, 0, 1, 8], device='cuda:0'),
#   tensor([0, 0, 0, 8, 3, 8, 5, 4, 3, 7, 1, 3, 3, 7, 1], device='cuda:0'),
#   tensor([1, 0, 4, 5, 6, 6, 4, 4, 0, 2, 3, 7, 6, 0, 0], device='cuda:0'),
#   tensor([6, 3, 3, 6, 7, 7, 6, 0, 5, 3, 8, 5, 6, 3, 0], device='cuda:0'),
#   tensor([5, 3, 6, 0, 0, 3, 5, 8, 0, 0, 3, 8, 0, 3, 4], device='cuda:0'),
#   tensor([0, 8, 4, 6, 0, 1, 7, 0, 2, 4, 0, 1, 0, 6, 3], device='cuda:0'),
#   tensor([4, 0, 4, 2, 3, 4, 7, 3, 1, 5, 7, 3, 5, 4, 0], device='cuda:0'),
#   tensor([5, 1, 4, 8, 5, 4, 0, 3, 8, 3, 8, 1, 2, 3, 7], device='cuda:0'),
#   tensor([5, 7, 5, 3, 6, 4, 8, 6, 4, 0, 5, 2, 3, 8, 8], device='cuda:0'),
#   tensor([0, 4, 2, 2, 6, 3, 6, 1, 0, 0, 0, 3, 0, 4, 8], device='cuda:0'),
#   tensor([3, 5, 2, 3, 0, 5, 4, 8, 3, 3, 0, 7, 4, 5, 3], device='cuda:0'),
#   tensor([6, 6, 2, 5, 5, 6, 7, 2, 8, 0, 5, 0, 2, 6, 7], device='cuda:0'),
#   tensor([3, 7, 4, 7, 4, 3, 2, 4, 5, 5, 1, 7, 3, 2, 0], device='cuda:0'),
#   tensor([6, 6, 8, 6, 0, 0, 3, 3, 0, 6, 2, 6, 0, 5, 1], device='cuda:0'),
#   tensor([7, 4, 8, 3, 4, 5, 2, 2, 1, 5, 7, 0, 0, 7, 7], device='cuda:0'),
#   tensor([3, 2, 6, 8, 5, 0, 4, 7, 4, 0, 0, 2, 7, 6, 5], device='cuda:0'),
#   tensor([8, 7, 4, 0, 0, 5, 8, 2, 2, 7, 3, 4, 6, 8, 2], device='cuda:0'),
#   tensor([5, 6, 5, 6, 7, 3, 5, 4, 7, 4, 8, 6, 0, 8, 2], device='cuda:0'),
#   tensor([6, 7, 6, 6, 5, 2, 8, 0, 3, 2, 7, 0, 2, 7, 7], device='cuda:0'),
#   tensor([6, 2, 6, 7, 4, 1, 4, 6, 5, 6, 7, 7, 8, 4, 4], device='cuda:0'),
#   tensor([2, 4, 2, 7, 5, 7, 2, 4, 4, 7, 6, 5, 6, 4, 6], device='cuda:0'),
#   tensor([4, 7, 6, 6, 6, 4, 4, 3, 4, 3, 2, 7, 6, 8, 2], device='cuda:0'),
#   tensor([1, 1, 2, 5, 2, 0, 2, 0, 7, 7, 0, 0, 4, 6, 8], device='cuda:0'),
#   tensor([0, 7, 8, 3, 4, 1, 1, 6, 0, 1, 3, 3, 4, 8, 4], device='cuda:0'),
#   tensor([6, 0, 8, 6, 1, 8, 8, 8, 2, 7, 6, 3, 6, 7, 7], device='cuda:0'),
#   tensor([2, 1, 2, 7, 2, 7, 7, 8, 4, 2, 3, 5, 5, 7, 6], device='cuda:0'),
#   tensor([3, 1, 3, 0, 2, 5, 6, 0, 3, 0, 4, 2, 3, 1, 2], device='cuda:0'),
#   tensor([1, 6, 4, 3, 3, 6, 5, 5, 3, 1, 3, 6, 7, 2, 3], device='cuda:0'),
#   tensor([3, 1, 1, 1, 5, 1, 6, 7, 1, 3, 8, 2, 3, 1, 5], device='cuda:0'),
#   tensor([0, 1, 8, 4, 6, 5, 4, 6, 2, 3, 6, 5, 3, 0, 1], device='cuda:0'),
#   tensor([0, 4, 0, 2, 3, 5, 7, 6, 6, 2, 2, 4, 3, 5, 5], device='cuda:0'),
#   tensor([4, 2, 2, 4, 0, 5, 4, 5, 3, 5, 0, 1, 5, 4, 0], device='cuda:0'),
#   tensor([7, 7, 6, 0, 4, 5, 6, 2, 2, 3, 3, 4, 5, 3, 5], device='cuda:0'),
#   tensor([6, 4, 3, 1, 4, 0, 3, 7, 0, 1, 2, 3, 6, 3, 1], device='cuda:0'),
#   tensor([3, 6, 0, 1, 3, 0, 6, 6, 1, 3, 8, 6, 7, 1, 4], device='cuda:0'),
#   tensor([6, 1, 1, 2, 4, 8, 2, 0, 3, 3, 8, 1, 8, 8, 4], device='cuda:0'),
#   tensor([4, 3, 2, 5, 3, 1, 8, 6, 6, 4, 1, 6, 2, 2, 2], device='cuda:0'),
#   tensor([6, 7, 8, 4, 8, 4, 5, 1, 1, 3, 3, 4, 8, 1, 2], device='cuda:0'),
#   tensor([0, 3, 8, 8, 0, 7, 6, 7, 5, 7, 4, 6, 5, 6, 5], device='cuda:0'),
#   tensor([8, 3, 7, 3, 6, 2, 2, 7, 7, 1, 8, 7, 5, 1, 0], device='cuda:0'),
#   tensor([1, 5, 4, 6, 0, 6, 2, 1, 0, 6, 3, 7, 6, 3, 5], device='cuda:0'),
#   tensor([7, 4, 0, 5, 8, 7, 5, 8, 4, 3, 7, 1, 4, 2, 6], device='cuda:0'),
#   tensor([6, 3, 2, 6, 4, 0, 6, 4, 7, 6, 5, 5, 6, 0, 4], device='cuda:0'),
#   tensor([7, 8, 1, 6, 6, 0, 4, 4, 5, 8, 6, 6, 6, 5, 3], device='cuda:0'),
#   tensor([7, 1, 1, 5, 1, 4, 1, 8, 1, 6, 6, 0, 6, 0, 0], device='cuda:0'),
#   tensor([0, 6, 1, 7, 2, 5, 8, 5, 0, 8, 3, 0, 1, 0, 5], device='cuda:0'),
#   tensor([3, 7, 1, 3, 2, 7, 8, 6, 7, 2, 1, 8, 0, 6, 0], device='cuda:0'),
#   tensor([6, 6, 8, 6, 1, 0, 1, 2, 6, 2, 4, 4, 5, 3, 4], device='cuda:0'),
#   tensor([2, 2, 8, 0, 4, 3, 2, 2, 3, 7, 4, 2, 5, 2, 4], device='cuda:0'),
#   tensor([5, 1, 2, 2, 7, 8, 4, 2, 0, 7, 3, 4, 1, 2, 7], device='cuda:0'),
#   tensor([7, 3, 0, 4, 6, 5, 8, 5, 4, 7, 5, 1, 5, 5, 7], device='cuda:0'),
#   tensor([7, 1, 5, 0, 5, 7, 0, 3, 0, 3, 6, 8, 7, 7, 8], device='cuda:0'),
#   tensor([1, 8, 5, 8, 5, 7, 3, 2, 2, 7, 3, 1, 2, 2, 0], device='cuda:0'),
#   tensor([4, 5, 5, 0, 7, 5, 0, 0, 5, 4, 6, 7, 3, 6, 1], device='cuda:0'),
#   tensor([5, 8, 1, 7, 5, 2, 8, 2, 5, 1, 0, 1, 5, 4, 5], device='cuda:0'),
#   tensor([7, 1, 5, 2, 2, 1, 8, 8, 8, 4, 6, 4, 3, 6, 3], device='cuda:0'),
#   tensor([6, 7, 0, 8, 4, 6, 5, 0, 7, 3, 4, 7, 0, 5, 0], device='cuda:0'),
#   tensor([3, 5, 2, 2, 0, 4, 2, 5, 5, 8, 2, 0, 5, 3, 7], device='cuda:0'),
#   tensor([7, 5, 8, 0, 7, 6, 4, 1, 1, 1, 7, 7, 1, 0, 0], device='cuda:0'),
#   tensor([7, 6, 0, 4, 4, 3, 7, 3, 7, 3, 5, 0, 3, 1, 4], device='cuda:0'),
#   tensor([0, 7, 7, 1, 8, 0, 8, 5, 2, 5, 5, 1, 5, 2, 3], device='cuda:0'),
#   tensor([8, 6, 2, 0, 0, 1, 3, 0, 0, 0, 0, 0, 6, 6, 6], device='cuda:0'),
#   tensor([7, 0, 2, 3, 0, 6, 3, 7, 0, 8, 7, 4, 0, 5, 1], device='cuda:0'),
#   tensor([5, 1, 5, 4, 0, 3, 4, 7, 5, 7, 6, 3, 4, 3, 6], device='cuda:0'),
#   tensor([1, 3, 0, 0, 8, 8, 6, 3, 6, 6, 6, 8, 4, 1, 2], device='cuda:0'),
#   tensor([5, 8, 7, 8, 4, 4, 5, 2, 0, 5, 5, 4, 4, 4, 1], device='cuda:0'),
#   tensor([4, 8, 0, 2, 5, 6, 1, 7, 2, 4, 7, 4, 3, 0, 8], device='cuda:0'),
#   tensor([5, 6, 3, 0, 8, 8, 0, 5, 6, 1, 0, 4, 7, 8, 5], device='cuda:0'),
#   tensor([2, 3, 6, 7, 7, 3, 0, 8, 4, 7, 7, 0, 4, 0, 6], device='cuda:0'),
#   tensor([4, 3, 6, 4, 4, 4, 2, 4, 2, 1, 4, 0, 6, 1, 1], device='cuda:0'),
#   tensor([7, 7, 7, 0, 4, 6, 1, 0, 8, 6, 6, 7, 1, 7, 6], device='cuda:0'),
#   tensor([8, 6, 8, 4, 4, 4, 2, 0, 5, 1, 1, 5, 1, 7, 2], device='cuda:0'),
#   tensor([2, 7, 5, 6, 1, 3, 0, 5, 1, 3, 7, 6, 3, 0, 0], device='cuda:0'),
#   tensor([1, 4, 5, 4, 0, 0, 5, 4, 2, 2, 4, 4, 2, 8, 8], device='cuda:0'),
#   tensor([6, 3, 4, 1, 0, 5, 8, 4, 8, 4, 1, 5, 5, 5, 5], device='cuda:0'),
#   tensor([0, 0, 5, 0, 7, 3, 4, 2, 7, 1, 1, 8, 4, 2, 3], device='cuda:0'),
#   tensor([1, 6, 6, 2, 7, 5, 6, 5, 0, 5, 7, 5, 5, 5, 3], device='cuda:0'),
#   tensor([1, 4, 5, 8, 2, 3, 5, 0, 2, 3, 5, 6, 1, 2, 6], device='cuda:0'),
#   tensor([6, 0, 5, 1, 7, 8, 7, 2, 2, 2, 0, 3, 4, 6, 7], device='cuda:0'),
#   tensor([5, 2, 4, 3, 4, 2, 5, 1, 4, 1, 8, 4, 3, 1, 5], device='cuda:0'),
#   tensor([5, 4, 8, 4, 0, 8, 7, 7, 7, 2, 2, 1, 7, 4, 7], device='cuda:0'),
#   tensor([6, 1, 4, 1, 3, 0, 5, 0, 4, 4, 6, 2, 0, 6, 8], device='cuda:0'),
#   tensor([3, 8, 8, 1, 6, 4, 6, 2, 4, 0, 5, 7, 1, 2, 5], device='cuda:0'),
#   tensor([4, 5, 1, 5, 3, 7, 4, 8, 2, 0, 7, 6, 5, 6, 4], device='cuda:0'),
#   tensor([2, 3, 0, 2, 4, 0, 2, 5, 2, 6, 7, 2, 6, 1, 8], device='cuda:0'),
#   tensor([0, 3, 0, 8, 6, 4, 7, 4, 6, 0, 1, 8, 8, 0, 1], device='cuda:0'),
#   tensor([2, 4, 4, 8, 5, 5, 8, 0, 7, 8, 6, 3, 1, 5, 3], device='cuda:0'),
#   tensor([3, 4, 7, 6, 3, 8, 7, 6, 2, 4, 0, 0, 7, 7, 4], device='cuda:0'),
#   tensor([5, 1, 2, 0, 8, 8, 3, 4, 4, 7, 8, 8, 0, 8, 8], device='cuda:0'),
#   tensor([4, 1, 3, 6, 2, 0, 5, 6, 0, 5, 7, 8, 1, 8, 3], device='cuda:0'),
#   tensor([0, 6, 8, 0, 6, 3, 3, 4, 8, 6, 5, 5, 8, 0, 0], device='cuda:0'),
#   tensor([6, 7, 6, 1, 7, 4, 8, 4, 0, 5, 5, 5, 0, 1, 8], device='cuda:0'),
#   tensor([8, 1, 0, 4, 8, 0, 1, 1, 1, 4, 4, 7, 1, 1, 0], device='cuda:0'),
#   tensor([1, 6, 8, 6, 6, 7, 5, 4, 7, 3, 0, 8, 3, 4, 1], device='cuda:0'),
#   tensor([8, 1, 4, 7, 4, 6, 6, 3, 3, 4, 3, 3, 2, 3, 4], device='cuda:0'),
#   tensor([2, 3, 0, 4, 5, 4, 4, 5, 0, 8, 0, 4, 6, 8, 6], device='cuda:0'),
#   tensor([5, 1, 6, 6, 0, 2, 6, 6, 8, 1, 5, 7, 8, 8, 6], device='cuda:0'),
#   tensor([4, 6, 8, 3, 6, 4, 3, 3, 3, 1, 8, 0, 8, 4, 6], device='cuda:0'),
#   tensor([4, 0, 4, 5, 7, 6, 5, 5, 3, 3, 5, 5, 6, 4, 7], device='cuda:0'),
#   tensor([6, 8, 3, 0, 8, 4, 3, 8, 0, 7, 2, 6, 5, 7, 8], device='cuda:0'),
#   tensor([6, 5, 1, 3, 4, 7, 3, 1, 4, 4, 3, 0, 6, 1, 4], device='cuda:0'),
#   tensor([6, 5, 1, 3, 0, 1, 1, 4, 8, 4, 8, 0, 0, 8, 4], device='cuda:0'),
#   tensor([8, 2, 3, 1, 8, 5, 8, 6, 1, 6, 6, 3, 5, 6, 3], device='cuda:0'),
#   tensor([3, 2, 3, 3, 8, 0, 6, 0, 5, 6, 0, 5, 3, 8, 8], device='cuda:0'),
#   tensor([6, 4, 0, 2, 3, 3, 8, 1, 6, 8, 5, 4, 4, 0, 0], device='cuda:0'),
#   tensor([2, 4, 1, 5, 3, 1, 6, 5, 4, 6, 4, 2, 6, 2, 7], device='cuda:0'),
#   tensor([7, 3, 6, 7, 6, 8, 4, 7, 4, 8, 4, 1, 6, 0, 8], device='cuda:0'),
#   tensor([4, 1, 3, 1, 4, 8, 5, 8, 4, 5, 8, 6, 8, 0, 2], device='cuda:0'),
#   tensor([1, 7, 0, 1, 8, 6, 8, 4, 0, 6, 0, 8, 3, 3, 6], device='cuda:0'),
#   tensor([1, 2, 0, 3, 7, 0, 1, 5, 2, 3, 6, 6, 1, 1, 0], device='cuda:0'),
#   tensor([7, 6, 2, 0, 7, 8, 4, 5, 5, 3, 6, 2, 4, 6, 1], device='cuda:0'),
#   tensor([1, 1, 3, 3, 6, 1, 3, 8, 3, 3, 7, 0, 5, 8, 7], device='cuda:0'),
#   tensor([3, 1, 5, 4, 1, 1, 3, 4, 1, 6, 3, 2, 3, 5, 5], device='cuda:0'),
#   tensor([1, 7, 5, 2, 5, 2, 8, 0, 8, 1, 2, 2, 8, 5, 0], device='cuda:0'),
#   tensor([8, 4, 0, 5, 0, 7, 4, 0, 0, 4, 2, 2, 6, 1, 4], device='cuda:0'),
#   tensor([5, 6, 6, 2, 5, 4, 1, 3, 7, 0, 1, 8, 0, 6, 6], device='cuda:0'),
#   tensor([7, 4, 8, 0, 5, 2, 1, 6, 6, 0, 1, 8, 3, 6, 5], device='cuda:0'),
#   tensor([5, 1, 2, 5, 6, 7, 8, 4, 2, 0, 1, 2, 5, 1, 5], device='cuda:0'),
#   tensor([4, 8, 7, 1, 8, 5, 7, 6, 5, 6, 2, 2, 0, 4, 4], device='cuda:0'),
#   tensor([0, 3, 3, 5, 3, 0, 0, 3, 1, 4, 4, 2, 5, 1, 5], device='cuda:0'),
#   tensor([2, 7, 5, 3, 8, 7, 3, 0, 4, 5, 6, 5, 2, 1, 1], device='cuda:0'),
#   tensor([2, 0, 1, 1, 4, 0, 0, 2, 0, 6, 3, 5, 3, 8, 1], device='cuda:0'),
#   tensor([0, 6, 4, 1, 1, 1, 3, 3, 7, 5, 1, 7, 6, 5, 5], device='cuda:0'),
#   tensor([1, 1, 1, 1, 8, 3, 2, 1, 8, 4, 8, 6, 2, 8, 1], device='cuda:0'),
#   tensor([0, 1, 1, 6, 2, 6, 3, 3, 7, 8, 6, 1, 8, 2, 4], device='cuda:0'),
#   tensor([2, 2, 4, 6, 2, 4, 3, 0, 3, 8, 0, 8, 1, 8, 7], device='cuda:0'),
#   tensor([0, 3, 0, 1, 1, 5, 0, 5, 2, 0, 7, 0, 7, 0, 1], device='cuda:0'),
#   tensor([5, 6, 1, 1, 6, 6, 2, 0, 4, 3, 5, 1, 5, 5, 6], device='cuda:0'),
#   tensor([7, 8, 7, 7, 1, 8, 3, 1, 0, 3, 7, 6, 2, 7, 3], device='cuda:0'),
#   tensor([8, 7, 4, 4, 2, 3, 2, 8, 5, 7, 5, 8, 0, 5, 0], device='cuda:0'),
#   tensor([0, 7, 6, 6, 8, 2, 6, 8, 5, 6, 2, 2, 7, 1, 8], device='cuda:0'),
#   tensor([8, 4, 7, 3, 2, 5, 0, 6, 3, 3, 2, 3, 6, 5, 2], device='cuda:0'),
#   tensor([0, 2, 7, 3, 2, 6, 8, 1, 6, 2, 2, 1, 3, 7, 8], device='cuda:0'),
#   tensor([2, 6, 0, 6, 1, 5, 4, 6, 1, 2, 6, 5, 8, 1, 1], device='cuda:0'),
#   tensor([5, 8, 6, 6, 6, 3, 3, 8, 2, 8, 4, 7, 6, 1, 4], device='cuda:0'),
#   tensor([6, 8, 2, 4, 1, 8, 0, 0, 2, 1, 2, 7, 6, 0, 7], device='cuda:0'),
#   tensor([4, 8, 2, 0, 4, 0, 1, 3, 4, 8, 7, 8, 6, 4, 0], device='cuda:0'),
#   tensor([1, 6, 5, 4, 0, 3, 2, 6, 2, 7, 5, 6, 0, 2, 3], device='cuda:0'),
#   tensor([1, 1, 4, 0, 2, 0, 3, 0, 2, 3, 2, 2, 5, 5, 5], device='cuda:0'),
#   tensor([5, 2, 2, 2, 0, 1, 8, 6, 8, 5, 4, 5, 6, 2, 3], device='cuda:0'),
#   tensor([4, 5, 8, 0, 0, 6, 2, 1, 1, 1, 1, 0, 4, 1, 6], device='cuda:0'),
#   tensor([2, 8, 5, 4, 0, 2, 2, 3, 6, 5, 8, 3, 7, 2, 4], device='cuda:0'),
#   tensor([6, 1, 2, 1, 3, 2, 3, 1, 8, 0, 0, 2, 0, 4, 6], device='cuda:0'),
#   tensor([8, 8, 8, 1, 8, 4, 0, 2, 6, 5, 0, 7, 6, 4, 4], device='cuda:0'),
#   tensor([0, 5, 5, 3, 0, 8, 3, 1, 3, 1, 7, 5, 8, 4, 4], device='cuda:0'),
#   tensor([1, 3, 4, 0, 4, 4, 5, 8, 4, 5, 8, 7, 8, 3, 5], device='cuda:0'),
#   tensor([0, 0, 7, 1, 6, 2, 2, 8, 4, 4, 0, 2, 5, 8, 5], device='cuda:0'),
#   tensor([7, 7, 5, 5, 5, 2, 7, 1, 6, 2, 8, 7, 4, 0, 7], device='cuda:0'),
#   tensor([3, 4, 1, 1, 5, 7, 3, 4, 3, 1, 5, 7, 5, 3, 7], device='cuda:0'),
#   tensor([1, 8, 4, 5, 8, 1, 4, 4, 5, 1, 4, 8, 2, 0, 3], device='cuda:0'),
#   tensor([8, 7, 8, 7, 5, 7, 3, 0, 3, 3, 3, 5, 5, 4, 4], device='cuda:0'),
#   tensor([0, 8, 4, 0, 2, 7, 8, 5, 6, 3, 6, 7, 5, 7, 8], device='cuda:0'),
#   tensor([5, 7, 7, 2, 4, 8, 1, 3, 5, 7, 5, 5, 5, 2, 7], device='cuda:0'),
#   tensor([0, 6, 8, 8, 4, 1, 2, 8, 3, 7, 1, 8, 6, 0, 5], device='cuda:0'),
#   tensor([7, 2, 5, 4, 4, 1, 3, 6, 7, 7, 4, 3, 6, 6, 1], device='cuda:0'),
#   tensor([3, 3, 7, 4, 0, 1, 3, 3, 2, 0, 4, 2, 1, 3, 2], device='cuda:0'),
#   tensor([0, 2, 4, 6, 5, 8, 4, 6, 1, 6, 5, 8, 5, 1, 0], device='cuda:0'),
#   tensor([7, 3, 1, 0, 5, 3, 7, 3, 1, 2, 6, 0, 4, 5, 5], device='cuda:0'),
#   tensor([1, 5, 0, 3, 3, 4, 0, 7, 3, 8, 4, 5, 1, 7, 2], device='cuda:0'),
#   tensor([0, 8, 3, 4, 8, 5, 0, 3, 2, 1, 5, 5, 1, 6, 1], device='cuda:0'),
#   tensor([3, 3, 5, 7, 8, 1, 3, 0, 7, 1, 7, 1, 5, 3, 7], device='cuda:0'),
#   tensor([1, 8, 8, 2, 4, 6, 2, 8, 5, 2, 0, 3, 6, 0, 3], device='cuda:0'),
#   tensor([8, 6, 3, 6, 1, 8, 6, 1, 0, 6, 2, 8, 7, 4, 4], device='cuda:0'),
#   tensor([6, 0, 7, 8, 1, 3, 2, 5, 3, 1, 4, 2, 6, 3, 4], device='cuda:0'),
#   tensor([6, 2, 8, 0, 5, 3, 6, 0, 1, 4, 8, 8, 1, 0, 7], device='cuda:0'),
#   tensor([7, 2, 7, 5, 5, 5, 4, 8, 5, 5, 6, 2, 0, 8, 1], device='cuda:0'),
#   tensor([0, 8, 2, 8, 0, 1, 5, 4, 5, 7, 7, 8, 5, 5, 3], device='cuda:0'),
#   tensor([3, 6, 0, 8, 7, 0, 8, 8, 0, 5, 6, 4, 6, 7, 0], device='cuda:0'),
#   tensor([1, 0, 5, 2, 1, 5, 6, 2, 1, 1, 0, 7, 0, 6, 1], device='cuda:0'),
#   tensor([8, 0, 3, 7, 6, 4, 7, 8, 5, 5, 0, 3, 6, 2, 3], device='cuda:0'),
#   tensor([1, 8, 2, 8, 6, 6, 5, 4, 4, 0, 2, 7, 3, 8, 6], device='cuda:0'),
#   tensor([5, 8, 5, 1, 8, 3, 1, 6, 8, 8, 0, 6, 4, 5, 2], device='cuda:0'),
#   tensor([0, 2, 4, 4, 0, 1, 8, 8, 3, 2, 2, 1, 3, 4, 0], device='cuda:0'),
#   tensor([7, 1, 4, 7, 2, 5, 0, 3, 1, 6, 1, 1, 4, 3, 6], device='cuda:0'),
#   tensor([6, 1, 0, 7, 1, 8, 6, 4, 2, 8, 8, 6, 1, 1, 0], device='cuda:0'),
#   tensor([8, 7, 0, 5, 0, 2, 3, 0, 8, 3, 2, 5, 8, 7, 5], device='cuda:0'),
#   tensor([6, 8, 7, 2, 7, 5, 8, 1, 8, 6, 5, 7, 6, 2, 5], device='cuda:0'),
#   tensor([6, 8, 2, 2, 5, 6, 1, 3, 7, 3, 4, 1, 8, 5, 3], device='cuda:0'),
#   tensor([7, 3, 7, 5, 6, 4, 5, 0, 3, 1, 3, 5, 8, 6, 8], device='cuda:0'),
#   tensor([2, 8, 5, 6, 2, 8, 5, 5, 7, 0, 6, 7, 8, 6, 1], device='cuda:0'),
#   tensor([1, 8, 5, 7, 0, 6, 2, 2, 5, 5, 7, 5, 8, 0, 5], device='cuda:0'),
#   tensor([7, 0, 7, 2, 0, 8, 3, 4, 3, 7, 4, 5, 1, 7, 2], device='cuda:0'),
#   tensor([5, 4, 5, 2, 3, 7, 1, 7, 5, 3, 5, 0, 4, 7, 6], device='cuda:0'),
#   tensor([0, 5, 2, 5, 7, 8, 4, 4, 4, 1, 7, 3, 4, 2, 8], device='cuda:0'),
#   tensor([7, 2, 1, 7, 5, 6, 6, 0, 3, 6, 3, 7, 7, 7, 8], device='cuda:0'),
#   tensor([2, 1, 2, 6, 4, 2, 6, 2, 6, 3, 6, 4, 7, 4, 6], device='cuda:0'),
#   tensor([7, 1, 2, 2, 7, 5, 7, 7, 1, 7, 3, 7, 7, 5, 8], device='cuda:0'),
#   tensor([7, 2, 2, 5, 1, 1, 1, 3, 1, 3, 8, 7, 2, 0, 7], device='cuda:0'),
#   tensor([0, 8, 3, 3, 3, 0, 1, 4, 0, 7, 8, 2, 7, 8, 6], device='cuda:0'),
#   tensor([1, 5, 1, 1, 4, 2, 7, 1, 6, 2, 5, 4, 7, 7, 0], device='cuda:0'),
#   tensor([6, 3, 8, 5, 4, 6, 3, 4, 2, 7, 0, 1, 2, 4, 3], device='cuda:0'),
#   tensor([7, 0, 6, 6, 4, 7, 2, 5, 4, 4, 6, 2, 0, 6, 8], device='cuda:0'),
#   tensor([8, 2, 1, 8, 0, 2, 4, 5, 5, 6, 3, 6, 8, 2, 6], device='cuda:0'),
#   tensor([5, 6, 6, 4, 2, 7, 3, 6, 7, 2, 4, 3, 3, 4, 4], device='cuda:0'),
#   tensor([7, 2, 5, 5, 3, 2, 3, 4, 5, 1, 1, 4, 6, 1, 4], device='cuda:0'),
#   tensor([3, 6, 0, 4, 0, 4, 7, 6, 6, 8, 3, 4, 1, 3, 2], device='cuda:0'),
#   tensor([0, 1, 4, 7, 0, 5, 1, 3, 1, 1, 2, 6, 4, 4, 6], device='cuda:0'),
#   tensor([1, 8, 1, 0, 3, 2, 5, 3, 2, 6, 1, 5, 5, 3, 3], device='cuda:0'),
#   tensor([2, 3, 4, 0, 3, 4, 0, 6, 0, 4, 1, 5, 5, 5, 8], device='cuda:0'),
#   tensor([6, 8, 8, 4, 2, 6, 3, 6, 3, 6, 5, 8, 6, 6, 5], device='cuda:0'),
#   tensor([4, 5, 7, 0, 3, 8, 4, 2, 2, 4, 5, 2, 0, 7, 6], device='cuda:0'),
#   tensor([3, 1, 4, 6, 8, 8, 7, 4, 5, 2, 0, 4, 5, 4, 3], device='cuda:0'),
#   tensor([6, 4, 8, 4, 3, 6, 5, 1, 5, 0, 1, 1, 5, 7, 3], device='cuda:0'),
#   tensor([0, 2, 0, 1, 6, 4, 4, 5, 7, 0, 5, 4, 7, 2, 2], device='cuda:0'),
#   tensor([4, 2, 2, 4, 0, 3, 5, 8, 4, 3, 8, 2, 0, 5, 3], device='cuda:0'),
#   tensor([4, 4, 6, 8, 2, 0, 5, 1, 6, 3, 7, 2, 3, 8, 7], device='cuda:0'),
#   tensor([2, 5, 6, 8, 7, 3, 4, 2, 3, 3, 0, 8, 1, 6, 3], device='cuda:0'),
#   tensor([1, 1, 4, 5, 1, 4, 4, 8, 4, 4, 5, 8, 6, 7, 4], device='cuda:0'),
#   tensor([7, 4, 4, 8, 3, 0, 1, 8, 3, 1, 0, 5, 2, 5, 0], device='cuda:0'),
#   tensor([1, 7, 8, 0, 5, 1, 6, 0, 8, 1, 8, 5, 8, 6, 5], device='cuda:0'),
#   tensor([5, 5, 6, 6, 3, 7, 5, 6, 3, 2, 8, 5, 8, 7, 1], device='cuda:0'),
#   tensor([4, 5, 0, 6, 8, 4, 7, 7, 0, 5, 8, 6, 8, 8, 1], device='cuda:0'),
#   tensor([4, 3, 2, 4, 6, 3, 5, 0, 4, 0, 0, 5, 0, 6, 7], device='cuda:0'),
#   tensor([3, 3, 8, 2, 6, 6, 8, 2, 5, 2, 2, 8, 1, 5, 7], device='cuda:0'),
#   tensor([6, 4, 4, 2, 0, 7, 4, 4, 3, 8, 2, 5, 1, 2, 5], device='cuda:0'),
#   tensor([2, 2, 2, 8, 7, 4, 8, 4, 2, 0, 5, 4, 0, 7, 0], device='cuda:0'),
#   tensor([4, 2, 5, 5, 3, 6, 4, 3, 5, 5, 5, 1, 4, 4, 1], device='cuda:0'),
#   tensor([2, 4, 2, 8, 6, 3, 7, 5, 6, 2, 3, 4, 7, 8, 8], device='cuda:0'),
#   tensor([5, 3, 3, 0, 7, 7, 3, 7, 8, 6, 0, 1, 8, 5, 1], device='cuda:0'),
#   tensor([5, 8, 5, 3, 5, 5, 8, 2, 4, 6, 3, 0, 4, 8, 7], device='cuda:0'),
#   tensor([2, 4, 6, 2, 3, 0, 5, 3, 6, 6, 5, 5, 5, 4, 8], device='cuda:0'),
#   tensor([3, 3, 2, 5, 0, 8, 8, 4, 4, 0, 5, 8, 6, 4, 4], device='cuda:0'),
#   tensor([3, 0, 4, 1, 4, 3, 5, 3, 1, 6, 0, 2, 4, 5, 5], device='cuda:0'),
#   tensor([7, 5, 1, 5, 1, 0, 8, 4, 7, 0, 7, 8, 1, 5, 6], device='cuda:0'),
#   tensor([8, 3, 7, 5, 6, 1, 7, 4, 8, 2, 5, 7, 7, 2, 4], device='cuda:0'),
#   tensor([2, 3, 7, 4, 4, 7, 2, 0, 5, 6, 2, 6, 2, 4, 1], device='cuda:0'),
#   tensor([4, 0, 2, 8, 8, 1, 6, 4, 6, 5, 2, 8, 5, 7, 7], device='cuda:0'),
#   tensor([0, 0, 2, 2, 0, 8, 8, 2, 5, 7, 5, 2, 1, 8, 0], device='cuda:0'),
#   tensor([6, 4, 5, 6, 2, 4, 4, 7, 1, 6, 8, 0, 5, 0, 8], device='cuda:0'),
#   tensor([4, 0, 0, 5, 0, 2, 8, 2, 7, 1, 6, 6, 3, 2, 7], device='cuda:0'),
#   tensor([2, 6, 4, 7, 7, 8, 4, 6, 3, 0, 0, 8, 4, 1, 2], device='cuda:0'),
#   tensor([3, 5, 2, 2, 3, 4, 5, 0, 6, 3, 8, 1, 1, 4, 8], device='cuda:0'),
#   tensor([2, 7, 2, 0, 0, 6, 2, 5, 0, 4, 2, 0, 8, 1, 1], device='cuda:0'),
#   tensor([5, 7, 5, 8, 6, 1, 5, 0, 6, 8, 0, 4, 6, 0, 2], device='cuda:0'),
#   tensor([4, 7, 8, 1, 2, 2, 0, 5, 8, 2, 8, 6, 3, 8, 2], device='cuda:0'),
#   tensor([4, 6, 4, 1, 8, 8, 7, 0, 4, 6, 5, 4, 3, 7, 0], device='cuda:0'),
#   tensor([2, 6, 6, 6, 8, 1, 3, 7, 7, 3, 6, 1, 7, 6, 2], device='cuda:0'),
#   tensor([2, 3, 3, 3, 4, 3, 0, 7, 5, 7, 2, 3, 1, 7, 8], device='cuda:0'),
#   tensor([4, 5, 7, 0, 2, 8, 5, 4, 8, 0, 4, 7, 0, 7, 6], device='cuda:0'),
#   tensor([7, 8, 1, 4, 5, 0, 5, 7, 2, 0, 0, 3, 4, 1, 8], device='cuda:0'),
#   tensor([5, 7, 2, 8, 6, 4, 0, 8, 6, 3, 8, 6, 5, 3, 8], device='cuda:0'),
#   tensor([0, 5, 7, 8, 8, 8, 5, 5, 6, 6, 0, 8, 1, 5, 3], device='cuda:0'),
#   tensor([7, 5, 0, 0, 5, 2, 4, 5, 6, 5, 1, 2, 7, 1, 3], device='cuda:0'),
#   tensor([0, 7, 6, 1, 3, 7, 6, 1, 2, 0, 6, 0, 6, 3, 5], device='cuda:0'),
#   tensor([8, 6, 7, 3, 0, 6, 7, 3, 4, 3, 7, 8, 5, 0, 5], device='cuda:0'),
#   tensor([6, 0, 0, 8, 4, 1, 5, 3, 0, 5, 7, 2, 0, 4, 8], device='cuda:0'),
#   tensor([1, 5, 0, 7, 3, 7, 7, 6, 5, 3, 5, 0, 4, 5, 7], device='cuda:0'),
#   tensor([1, 3, 6, 7, 6, 3, 4, 6, 1, 1, 8, 7, 3, 0, 0], device='cuda:0'),
#   tensor([8, 0, 0, 3, 1, 0, 6, 7, 6, 2, 5, 7, 8, 8, 7], device='cuda:0'),
#   tensor([4, 1, 1, 8, 0, 1, 1, 6, 7, 0, 5, 0, 7, 8, 1], device='cuda:0'),
#   tensor([8, 2, 4, 7, 7, 0, 4, 8, 2, 7, 4, 0, 0, 1, 7], device='cuda:0'),
#   tensor([8, 1, 7, 7, 2, 5, 2, 3, 1, 4, 8, 2, 6, 3, 2], device='cuda:0'),
#   tensor([2, 4, 0, 8, 4, 2, 7, 8, 4, 0, 1, 1, 4, 6, 5], device='cuda:0'),
#   tensor([8, 5, 6, 2, 7, 1, 0, 3, 8, 6, 1, 5, 6, 8, 3], device='cuda:0'),
#   tensor([0, 4, 5, 0, 6, 2, 0, 3, 5, 3, 2, 6, 5, 8, 1], device='cuda:0'),
#   tensor([3, 6, 8, 0, 7, 0, 1, 6, 6, 6, 6, 7, 7, 5, 6], device='cuda:0'),
#   tensor([5, 1, 8, 3, 5, 3, 5, 3, 4, 8, 3, 2, 5, 5, 6], device='cuda:0'),
#   tensor([6, 5, 0, 8, 8, 3, 8, 1, 4, 1, 3, 7, 1, 2, 8], device='cuda:0'),
#   tensor([8, 3, 1, 2, 4, 8, 0, 4, 1, 7, 6, 0, 1, 8, 0], device='cuda:0'),
#   tensor([4, 5, 5, 2, 0, 2, 4, 2, 3, 8, 7, 2, 2, 3, 7], device='cuda:0'),
#   tensor([1, 1, 4, 5, 2, 1, 3, 3, 0, 0, 6, 4, 2, 8, 2], device='cuda:0'),
#   tensor([1, 7, 1, 8, 8, 8, 4, 8, 3, 8, 0, 6, 6, 2, 8], device='cuda:0'),
#   tensor([3, 7, 5, 3, 7, 1, 1, 6, 0, 6, 8, 1, 3, 5, 8], device='cuda:0'),
#   tensor([1, 7, 0, 1, 7, 1, 5, 8, 2, 5, 6, 3, 3, 3, 6], device='cuda:0'),
#   tensor([2, 3, 8, 8, 4, 5, 4, 5, 7, 3, 4, 4, 5, 7, 5], device='cuda:0'),
#   tensor([1, 2, 7, 7, 3, 8, 6, 5, 7, 8, 1, 2, 6, 2, 8], device='cuda:0'),
#   tensor([3, 6, 5, 5, 1, 0, 3, 5, 5, 8, 0, 5, 1, 4, 6], device='cuda:0'),
#   tensor([4, 4, 4, 0, 8, 0, 7, 2, 3, 5, 7, 4, 4, 3, 5], device='cuda:0'),
#   tensor([6, 7, 5, 3, 5, 7, 2, 7, 4, 6, 5, 8, 5, 1, 3], device='cuda:0'),
#   tensor([8, 5, 1, 2, 8, 7, 1, 1, 6, 7, 0, 8, 7, 7, 6], device='cuda:0'),
#   tensor([6, 6, 1, 3, 8, 8, 7, 2, 3, 7, 2, 7, 3, 5, 1], device='cuda:0'),
#   tensor([5, 4, 0, 4, 1, 5, 5, 1, 6, 8, 3, 6, 7, 6, 2], device='cuda:0'),
#   tensor([2, 6, 2, 3, 7, 8, 8, 6, 7, 7, 3, 0, 7, 8, 5], device='cuda:0'),
#   tensor([2, 3, 4, 4, 4, 7, 1, 0, 1, 2, 2, 1, 8, 4, 6], device='cuda:0'),
#   tensor([7, 5, 0, 1, 0, 7, 2, 7, 2, 6, 1, 0, 8, 0, 6], device='cuda:0'),
#   tensor([2, 1, 3, 1, 7, 5, 7, 7, 5, 0, 6, 8, 5, 6, 1], device='cuda:0'),
#   tensor([2, 2, 2, 4, 7, 6, 1, 8, 0, 7, 5, 4, 3, 4, 4], device='cuda:0'),
#   tensor([3, 2, 6, 4, 5, 2, 4, 4, 1, 4, 4, 8, 6, 3, 5], device='cuda:0'),
#   tensor([4, 8, 5, 0, 5, 0, 4, 0, 7, 8, 7, 8, 6, 4, 6], device='cuda:0'),
#   tensor([5, 4, 2, 4, 2, 2, 0, 2, 6, 4, 2, 6, 6, 0, 7], device='cuda:0'),
#   tensor([3, 3, 7, 1, 3, 8, 6, 2, 2, 1, 2, 4, 4, 8, 6], device='cuda:0'),
#   tensor([0, 6, 4, 5, 1, 0, 6, 0, 4, 3, 7, 2, 0, 8, 2], device='cuda:0'),
#   tensor([3, 6, 0, 5, 8, 5, 5, 8, 0, 4, 2, 5, 7, 5, 7], device='cuda:0'),
#   tensor([5, 2, 5, 1, 1, 3, 5, 5, 5, 7, 5, 1, 3, 6, 0], device='cuda:0'),
#   tensor([3, 1, 1, 4, 4, 5, 3, 8, 3, 3, 7, 1, 7, 1, 8], device='cuda:0'),
#   tensor([6, 0, 3, 5, 7, 7, 5, 4, 2, 8, 2, 6, 4, 4, 0], device='cuda:0'),
#   tensor([1, 5, 4, 3, 1, 8, 8, 1, 5, 4, 3, 6, 5, 1, 5], device='cuda:0'),
#   tensor([6, 2, 4, 2, 5, 6, 2, 5, 7, 2, 8, 2, 8, 7, 4], device='cuda:0'),
#   tensor([1, 2, 7, 2, 1, 3, 1, 5, 4, 8, 6, 5, 6, 7, 5], device='cuda:0'),
#   tensor([4, 8, 2, 3, 4, 4, 8, 8, 5, 7, 6, 8, 3, 4, 6], device='cuda:0'),
#   tensor([4, 1, 3, 7, 0, 7, 3, 4, 8, 7, 5, 2, 6, 6, 0], device='cuda:0'),
#   tensor([8, 4, 4, 7, 7, 0, 8, 1, 2, 1, 2, 3, 2, 6, 4], device='cuda:0'),
#   tensor([1, 2, 7, 7, 8, 5, 1, 0, 2, 7, 7, 2, 6, 7, 2], device='cuda:0'),
#   tensor([0, 7, 3, 7, 1, 7, 3, 8, 0, 0, 7, 8, 5, 7, 4], device='cuda:0'),
#   tensor([6, 2, 1, 4, 8, 8, 6, 0, 0, 4, 0, 2, 8, 0, 8], device='cuda:0'),
#   tensor([5, 8, 3, 5, 5, 3, 8, 5, 2, 1, 8, 4, 8, 8, 3], device='cuda:0'),
#   tensor([2, 0, 2, 7, 6, 8, 5, 1, 7, 7, 5, 1, 1, 3, 2], device='cuda:0'),
#   tensor([8, 4, 3, 5, 5, 7, 8, 6, 7, 8, 6, 4, 8, 8, 4], device='cuda:0'),
#   tensor([0, 1, 2, 5, 3, 4, 5, 6, 5, 5, 6, 8, 8, 0, 4], device='cuda:0'),
#   tensor([0, 3, 5, 4, 1, 0, 6, 4, 4, 6, 5, 8, 6, 6, 2], device='cuda:0'),
#   tensor([3, 4, 5, 3, 0, 8, 2, 5, 1, 7, 4, 2, 4, 7, 2], device='cuda:0'),
#   tensor([4, 8, 0, 7, 5, 0, 1, 8, 4, 8, 6, 6, 6, 3, 4], device='cuda:0'),
#   tensor([0, 1, 6, 8, 5, 6, 5, 4, 7, 1, 6, 0, 4, 0, 5], device='cuda:0'),
#   tensor([5, 4, 0, 5, 7, 7, 5, 7, 2, 4, 3, 3, 0, 0, 2], device='cuda:0'),
#   tensor([6, 0, 4, 5, 2, 2, 6, 5, 0, 0, 1, 2, 8, 6, 6], device='cuda:0'),
#   tensor([3, 5, 3, 4, 2, 5, 3, 4, 2, 4, 1, 7, 5, 7, 5], device='cuda:0'),
#   tensor([0, 0, 2, 5, 5, 6, 4, 1, 2, 3, 7, 3, 4, 5, 1], device='cuda:0'),
#   tensor([3, 3, 2, 8, 3, 4, 2, 2, 6, 4, 4, 6, 3, 1, 4], device='cuda:0'),
#   tensor([0, 4, 1, 3, 4, 7, 1, 3, 4, 3, 5, 8, 0, 1, 4], device='cuda:0'),
#   tensor([1, 5, 5, 7, 0, 6, 8, 4, 2, 3, 3, 1, 0, 2, 2], device='cuda:0'),
#   tensor([6, 4, 7, 7, 0, 4, 0, 7, 4, 6, 2, 1, 1, 6, 6], device='cuda:0'),
#   tensor([7, 1, 7, 2, 8, 2, 2, 6, 2, 4, 7, 2, 4, 3, 1], device='cuda:0'),
#   tensor([7, 3, 7, 6, 0, 4, 6, 6, 6, 6, 1, 2, 2, 3, 0], device='cuda:0'),
#   tensor([7, 2, 4, 4, 7, 1, 1, 5, 5, 0, 3, 8, 1, 3, 5], device='cuda:0'),
#   tensor([1, 0, 8, 2, 0, 5, 1, 0, 7, 5, 4, 5, 8, 3, 8], device='cuda:0'),
#   tensor([3, 7, 6, 3, 7, 8, 4, 0, 5, 8, 0, 1, 1, 0, 8], device='cuda:0'),
#   tensor([5, 7, 5, 5, 4, 1, 5, 4, 3, 8, 6, 1, 7, 4, 4], device='cuda:0'),
#   tensor([7, 8, 0, 4, 4, 7, 4, 1, 0, 6, 8, 3, 3, 1, 2], device='cuda:0'),
#   tensor([7, 4, 5, 1, 1, 2, 7, 5, 2, 5, 1, 3, 1, 5, 5], device='cuda:0'),
#   tensor([0, 4, 1, 5, 6, 8, 6, 4, 2, 1, 7, 8, 6, 4, 1], device='cuda:0'),
#   tensor([5, 0, 0, 5, 5, 5, 2, 0, 3, 3, 2, 3, 4, 6, 0], device='cuda:0'),
#   tensor([7, 1, 0, 2, 7, 5, 0, 7, 7, 4, 5, 6, 7, 8, 5], device='cuda:0'),
#   tensor([4, 6, 0, 3, 1, 6, 2, 7, 0, 6, 5, 0, 7, 1, 5], device='cuda:0'),
#   tensor([3, 6, 4, 7, 7, 7, 6, 1, 0, 6, 5, 2, 7, 4, 8], device='cuda:0'),
#   tensor([6, 6, 4, 6, 6, 0, 8, 3, 7, 0, 2, 7, 7, 7, 4], device='cuda:0'),
#   tensor([2, 6, 0, 7, 6, 8, 6, 4, 6, 0, 5, 7, 7, 5, 7], device='cuda:0'),
#   tensor([3, 3, 2, 8, 3, 8, 6, 2, 5, 0, 2, 0, 2, 5, 4], device='cuda:0'),
#   tensor([5, 6, 3, 2, 2, 8, 5, 2, 6, 7, 2, 3, 1, 1, 5], device='cuda:0'),
#   tensor([2, 7, 7, 2, 5, 2, 2, 2, 5, 2, 5, 0, 5, 2, 0], device='cuda:0'),
#   tensor([2, 0, 3, 1, 7, 8, 0, 6, 7, 8, 6, 5, 1, 3, 5], device='cuda:0'),
#   tensor([6, 4, 5, 6, 8, 2, 7, 4, 1, 0, 4, 6, 6, 6, 7], device='cuda:0'),
#   tensor([5, 4, 3, 6, 0, 7, 2, 2, 5, 6, 2, 4, 8, 1, 4], device='cuda:0'),
#   tensor([0, 5, 3, 6, 8, 5, 6, 0, 0, 8, 1, 0, 5, 4, 1], device='cuda:0'),
#   tensor([7, 6, 1, 4, 5, 2, 4, 4, 4, 5, 1, 5, 8, 2, 8], device='cuda:0'),
#   tensor([1, 4, 4, 2, 3, 7, 5, 6, 7, 3, 6, 7, 0, 1, 2], device='cuda:0'),
#   tensor([3, 7, 6, 4, 8, 6, 1, 6, 1, 7, 6, 1, 6, 7, 3], device='cuda:0'),
#   tensor([7, 4, 3, 1, 8, 4, 2, 3, 3, 1, 0, 1, 5, 7, 3], device='cuda:0'),
#   tensor([8, 6, 5, 8, 2, 3, 4, 7, 2, 2, 7, 6, 0, 4, 5], device='cuda:0'),
#   tensor([7, 2, 1, 5, 4, 1, 6, 6, 2, 7, 1, 7, 0, 6, 1], device='cuda:0'),
#   tensor([3, 5, 3, 7, 0, 1, 5, 4, 6, 7, 1, 5, 8, 8, 6], device='cuda:0'),
#   tensor([5, 5, 5, 8, 5, 8, 5, 0, 7, 0, 6, 8, 6, 8, 8], device='cuda:0'),
#   tensor([7, 7, 5, 1, 0, 4, 3, 3, 5, 6, 7, 8, 5, 3, 7], device='cuda:0'),
#   tensor([2, 3, 6, 7, 8, 5, 6, 1, 1, 1, 5, 0, 7, 4, 2], device='cuda:0'),
#   tensor([0, 5, 4, 6, 4, 2, 5, 6, 0, 1, 3, 8, 1, 6, 2], device='cuda:0'),
#   tensor([5, 8, 7, 6, 6, 5, 1, 8, 6, 5, 0, 5, 1, 2, 1], device='cuda:0'),
#   tensor([5, 5, 5, 7, 7, 4, 8, 4, 4, 6, 6, 7, 3, 8, 1], device='cuda:0'),
#   tensor([8, 6, 2, 1, 1, 0, 8, 3, 5, 4, 5, 7, 6, 6, 8], device='cuda:0'),
#   tensor([8, 5, 5, 5, 8, 4, 8, 1, 0, 8, 7, 6, 2, 7, 4], device='cuda:0'),
#   tensor([5, 8, 3, 8, 8, 2, 0, 1, 0, 5, 5, 6, 5, 5, 7], device='cuda:0'),
#   tensor([8, 2, 1, 8, 7, 0, 1, 8, 8, 5, 8, 1, 5, 1, 5], device='cuda:0'),
#   tensor([1, 6, 6, 6, 7, 8, 8, 7, 2, 8, 7, 5, 0, 3, 8], device='cuda:0'),
#   tensor([8, 2, 3, 6, 8, 2, 4, 4, 5, 4, 8, 8, 5, 5, 8], device='cuda:0'),
#   tensor([2, 6, 1, 0, 3, 8, 3, 7, 5, 0, 4, 6, 5, 6, 7], device='cuda:0'),
#   tensor([3, 7, 6, 6, 2, 1, 0, 2, 8, 2, 2, 8, 5, 4, 5], device='cuda:0'),
#   tensor([8, 6, 0, 5, 6, 8, 4, 4, 6, 0, 2, 4, 8, 8, 4], device='cuda:0'),
#   tensor([6, 2, 2, 3, 0, 1, 1, 3, 5, 5, 2, 1, 7, 8, 2], device='cuda:0'),
#   tensor([4, 4, 0, 1, 0, 6, 7, 0, 4, 2, 4, 8, 6, 1, 0], device='cuda:0'),
#   tensor([4, 5, 3, 8, 3, 6, 8, 6, 0, 8, 2, 8, 6, 4, 0], device='cuda:0'),
#   tensor([7, 1, 7, 8, 2, 8, 1, 1, 3, 6, 2, 3, 7, 5, 4], device='cuda:0'),
#   tensor([8, 6, 0, 7, 6, 8, 6, 1, 5, 4, 6, 5, 6, 0, 4], device='cuda:0'),
#   tensor([4, 8, 1, 3, 2, 6, 4, 8, 8, 0, 1, 2, 8, 2, 0], device='cuda:0'),
#   tensor([5, 8, 5, 0, 4, 8, 8, 8, 0, 7, 0, 2, 2, 4, 4], device='cuda:0'),
#   tensor([5, 2, 2, 4, 8, 4, 1, 3, 2, 5, 4, 2, 5, 8, 6], device='cuda:0'),
#   tensor([6, 5, 0, 1, 6, 8, 2, 2, 2, 4, 8, 8, 5, 1, 3], device='cuda:0'),
#   tensor([3, 3, 8, 2, 1, 2, 2, 4, 5, 3, 4, 0, 2, 2, 1], device='cuda:0'),
#   tensor([4, 4, 4, 2, 6, 4, 1, 5, 0, 2, 6, 5, 8, 6, 5], device='cuda:0'),
#   tensor([2, 5, 5, 2, 4, 0, 3, 3, 5, 6, 1, 1, 4, 0, 4], device='cuda:0'),
#   tensor([1, 3, 4, 5, 8, 8, 2, 0, 1, 8, 5, 1, 5, 2, 1], device='cuda:0'),
#   tensor([2, 4, 4, 1, 1, 6, 4, 7, 0, 4, 8, 2, 2, 0, 0], device='cuda:0'),
#   tensor([5, 4, 1, 2, 4, 7, 2, 1, 4, 2, 6, 1, 5, 3, 2], device='cuda:0'),
#   tensor([3, 1, 2, 4, 0, 5, 6, 7, 8, 2, 8, 1, 7, 2, 5], device='cuda:0'),
#   tensor([2, 1, 6, 0, 1, 2, 8, 1, 7, 8, 6, 5, 5, 6, 0], device='cuda:0'),
#   tensor([5, 8, 8, 4, 2, 4, 6, 6, 2, 1, 2, 0, 2, 4, 0], device='cuda:0'),
#   tensor([4, 0, 8, 4, 3, 6, 3, 5, 8, 5, 0, 1, 4, 4, 6], device='cuda:0'),
#   tensor([1, 1, 2, 5, 5, 1, 2, 5, 3, 8, 4, 1, 7, 8, 4], device='cuda:0'),
#   tensor([1, 5, 1, 5, 8, 7, 1, 3, 4, 2, 1, 3, 4, 2, 3], device='cuda:0'),
#   tensor([1, 2, 3, 0, 8, 6, 0, 4, 6, 3, 0, 0, 4, 5, 3], device='cuda:0'),
#   tensor([2, 7, 4, 2, 6, 2, 0, 8, 5, 8, 1, 2, 3, 8, 8], device='cuda:0'),
#   tensor([0, 4, 2, 3, 4, 1, 1, 3, 1, 6, 2, 7, 6, 1, 4], device='cuda:0'),
#   tensor([0, 4, 1, 4, 7, 5, 8, 5, 2, 8, 1, 5, 4, 4, 6], device='cuda:0'),
#   tensor([6, 5, 1, 2, 8, 4, 2, 1, 4, 3, 1, 3, 6, 0, 1], device='cuda:0'),
#   tensor([0, 2, 7, 3, 6, 2, 3, 1, 2, 1, 8, 4, 2, 4, 5], device='cuda:0'),
#   tensor([4, 0, 0, 8, 8, 7, 0, 6, 7, 4, 0, 7, 5, 5, 6], device='cuda:0'),
#   tensor([5, 5, 2, 6, 4, 2, 7, 8, 1, 2, 4, 2, 7, 6, 4], device='cuda:0'),
#   tensor([8, 4, 5, 6, 5, 0, 5, 4, 5, 8, 3, 2, 6, 8, 7], device='cuda:0'),
#   tensor([3, 1, 6, 0, 2, 5, 3, 8, 0, 0, 5, 8, 4, 0, 5], device='cuda:0'),
#   tensor([4, 0, 0, 0, 2, 8, 3, 2, 8, 8, 2, 3, 2, 2, 1], device='cuda:0'),
#   tensor([6, 0, 1, 1, 8, 3, 4, 3, 6, 4, 1, 1, 1, 3, 0], device='cuda:0'),
#   tensor([5, 1, 3, 6, 3, 7, 7, 0, 1, 4, 3, 2, 4, 8, 1], device='cuda:0'),
#   tensor([1, 1, 1, 5, 1, 6, 1, 0, 4, 1, 8, 1, 5, 8, 0], device='cuda:0'),
#   tensor([7, 1, 2, 5, 7, 8, 3, 3, 6, 3, 2, 0, 2, 5, 8], device='cuda:0'),
#   tensor([6, 7, 4, 0, 4, 0, 1, 2, 1, 2, 2, 0, 7, 8, 6], device='cuda:0'),
#   tensor([3, 6, 8, 2, 0, 8, 2, 2, 1, 1, 3, 4, 5, 3, 6], device='cuda:0'),
#   tensor([4, 2, 4, 7, 6, 4, 8, 0, 3, 7, 0, 7, 0, 1, 2], device='cuda:0'),
#   tensor([1, 4, 4, 8, 7, 1, 4, 7, 5, 4, 5, 5, 6, 3, 1], device='cuda:0'),
#   tensor([7, 0, 1, 0, 6, 1, 2, 7, 8, 6, 3, 8, 6, 0, 5], device='cuda:0'),
#   tensor([2, 1, 4, 6, 4, 6, 4, 6, 0, 4, 1, 3, 2, 4, 4], device='cuda:0'),
#   tensor([3, 7, 6, 3, 0, 2, 1, 5, 0, 8, 6, 8, 5, 6, 7], device='cuda:0'),
#   tensor([6, 0, 4, 1, 1, 0, 7, 6, 0, 0, 6, 0, 4, 6, 1], device='cuda:0'),
#   tensor([3, 4, 2, 5, 2, 1, 4, 7, 6, 1, 5, 2, 1, 8, 6], device='cuda:0'),
#   tensor([3, 5, 5, 1, 8, 8, 7, 8, 2, 8, 1, 8, 6, 4, 6], device='cuda:0'),
#   tensor([5, 4, 8, 4, 0, 3, 7, 2, 8, 7, 8, 0, 2, 3, 8], device='cuda:0'),
#   tensor([0, 4, 3, 8, 2, 1, 0, 6, 7, 8, 3, 3, 8, 1, 3], device='cuda:0'),
#   tensor([2, 3, 0, 4, 3, 4, 8, 5, 0, 3, 0, 2, 2, 8, 8], device='cuda:0'),
#   tensor([6, 7, 3, 8, 5, 8, 8, 4, 7, 2, 7, 8, 5, 1, 5], device='cuda:0'),
#   tensor([5, 4, 3, 1, 5, 5, 6, 7, 1, 4, 4, 7, 1, 3, 1], device='cuda:0'),
#   tensor([5, 6, 5, 8, 2, 7, 6, 6, 7, 3, 1, 7, 5, 8, 4], device='cuda:0'),
#   tensor([7, 2, 7, 0, 8, 8, 5, 8, 8, 5, 0, 0, 1, 1, 2], device='cuda:0'),
#   tensor([7, 4, 8, 7, 7, 2, 7, 3, 4, 2, 6, 3, 6, 2, 1], device='cuda:0'),
#   tensor([8, 7, 0, 5, 1, 7, 4, 5, 7, 8, 1, 5, 2, 7, 8], device='cuda:0'),
#   tensor([5, 1, 7, 4, 1, 8, 1, 7, 5, 1, 7, 4, 7, 7, 1], device='cuda:0'),
#   tensor([5, 1, 5, 3, 2, 6, 8, 1, 8, 4, 7, 6, 5, 1, 8], device='cuda:0'),
#   tensor([3, 3, 5, 3, 8, 0, 0, 5, 6, 2, 5, 8, 7, 5, 4], device='cuda:0'),
#   tensor([7, 3, 1, 2, 6, 3, 5, 3, 3, 4, 4, 3, 6, 4, 6], device='cuda:0'),
#   tensor([3, 2, 6, 3, 4, 4, 6, 7, 0, 3, 3, 7, 6, 1, 0], device='cuda:0'),
#   tensor([4, 8, 2, 0, 4, 5, 6, 1, 8, 0, 5, 3, 1, 5, 1], device='cuda:0'),
#   tensor([3, 8, 7, 1, 1, 5, 5, 5, 5, 3, 2, 0, 3, 6, 4], device='cuda:0'),
#   tensor([6, 5, 4, 1, 4, 7, 6, 1, 7, 2, 8, 0, 3, 8, 0], device='cuda:0'),
#   tensor([7, 4, 7, 4, 6, 8, 7, 5, 6, 3, 4, 8, 8, 5, 8], device='cuda:0'),
#   tensor([4, 6, 6, 0, 0, 6, 4, 6, 1, 1, 8, 3, 4, 3, 4], device='cuda:0'),
#   tensor([6, 7, 7, 5, 2, 6, 0, 5, 6, 7, 4, 6, 4, 0, 6], device='cuda:0'),
#   tensor([7, 6, 2, 4, 3, 0, 1, 7, 2, 2, 7, 0, 6, 6, 4], device='cuda:0'),
#   tensor([0, 2, 7, 7, 0, 3, 3, 3, 5, 4, 8, 0, 3, 6, 8], device='cuda:0'),
#   tensor([4, 1, 6, 8, 2, 4, 8, 2, 7, 3, 7, 8, 3, 3, 1], device='cuda:0'),
#   tensor([2, 1, 3, 1, 4, 4, 1, 1, 4, 7, 4, 0, 3, 6, 0], device='cuda:0'),
#   tensor([6, 8, 5, 3, 1, 6, 1, 0, 0, 7, 2, 8, 6, 3, 1], device='cuda:0'),
#   tensor([6, 7, 2, 6, 1, 1, 5, 1, 2, 1, 4, 1, 2, 7, 7], device='cuda:0'),
#   tensor([8, 7, 4, 3, 3, 1, 4, 8, 1, 7, 2, 6, 1, 1, 1], device='cuda:0'),
#   tensor([7, 8, 8, 8, 8, 7, 4, 2, 1, 7, 5, 2, 3, 1, 3], device='cuda:0'),
#   tensor([0, 3, 1, 2, 3, 7, 2, 0, 0, 0, 6, 6, 6, 7, 1], device='cuda:0'),
#   tensor([4, 0, 5, 1, 4, 6, 2, 1, 4, 2, 5, 7, 6, 5, 1], device='cuda:0'),
#   tensor([1, 6, 4, 5, 0, 1, 1, 8, 2, 8, 8, 6, 0, 4, 8], device='cuda:0'),
#   tensor([3, 5, 8, 4, 6, 1, 8, 6, 1, 7, 4, 6, 5, 6, 6], device='cuda:0'),
#   tensor([7, 2, 3, 5, 6, 4, 4, 3, 7, 1, 6, 8, 1, 7, 1], device='cuda:0'),
#   tensor([1, 6, 5, 6, 0, 1, 0, 2, 8, 0, 5, 7, 1, 0, 2], device='cuda:0'),
#   tensor([1, 6, 0, 8, 1, 0, 7, 7, 2, 2, 4, 7, 4, 8, 2], device='cuda:0'),
#   tensor([5, 6, 1, 2, 2, 4, 2, 1, 4, 6, 1, 2, 0, 6, 8], device='cuda:0'),
#   tensor([2, 5, 7, 0, 0, 4, 3, 8, 4, 4, 5, 5, 8, 7, 8], device='cuda:0'),
#   tensor([7, 8, 4, 8, 1, 5, 6, 7, 3, 3, 4, 2, 8, 2, 4], device='cuda:0'),
#   tensor([5, 3, 0, 7, 8, 3, 1, 5, 8, 8, 0, 6, 7, 4, 1], device='cuda:0'),
#   tensor([2, 7, 4, 8, 1, 2, 8, 0, 6, 5, 7, 8, 6, 5, 5], device='cuda:0'),
#   tensor([4, 6, 2, 7, 0, 8, 7, 0, 8, 0, 4, 2, 1, 0, 6], device='cuda:0'),
#   tensor([5, 4, 5, 0, 5, 5, 7, 1, 5, 2, 6, 1, 7, 8, 2], device='cuda:0'),
#   tensor([0, 1, 1, 5, 3, 7, 4, 0, 8, 8, 0, 7, 1, 2, 6], device='cuda:0'),
# ...
#   tensor([2, 5, 0, 5, 2, 6, 4, 5, 1, 4, 6, 8, 6, 4, 3], device='cuda:0'),
#   tensor([4, 4, 4, 0, 0, 5, 5, 5, 3, 0, 5, 5, 5, 0, 7], device='cuda:0'),
#   tensor([3, 3, 6, 7, 0, 3, 4, 8, 6, 2, 1, 8, 2, 1, 7], device='cuda:0'),
#   tensor([7, 5, 2, 5, 8, 6, 0, 2, 6, 4, 1, 0, 3, 5, 0], device='cuda:0'),
#   tensor([5, 0, 7, 3, 0, 1, 8, 6, 0, 4, 2, 0, 1, 4, 8], device='cuda:0'),
#   tensor([1, 0, 8, 6, 4, 3, 1, 5, 5, 1, 0, 6, 7, 1, 0], device='cuda:0'),
#   tensor([3, 4, 8, 1, 2, 0, 3, 8, 8, 0, 1, 4, 3, 1, 5], device='cuda:0'),
#   tensor([8, 8, 8, 3, 2, 0, 8, 5, 2, 3, 2, 0, 2, 7, 8], device='cuda:0'),
#   tensor([3, 8, 8, 8, 3, 4, 7, 6, 0, 4, 8, 4, 5, 8, 0], device='cuda:0'),
#   tensor([8, 5, 0, 0, 4, 3, 1, 1, 8, 6, 4, 4, 7, 2, 5], device='cuda:0'),
#   tensor([1, 8, 3, 6, 3, 3, 2, 2, 2, 6, 3, 4, 0, 5, 3], device='cuda:0'),
#   tensor([7, 7, 7, 3, 6, 0, 0, 6, 2, 8, 0, 5, 1, 3, 8], device='cuda:0'),
#   tensor([6, 6, 4, 0, 6, 0, 5, 2, 1, 5, 7, 8, 7, 8, 8], device='cuda:0'),
#   tensor([6, 2, 8, 6, 6, 8, 6, 7, 8, 0, 0, 8, 3, 3, 6], device='cuda:0'),
#   tensor([7, 2, 8, 2, 8, 3, 7, 0, 6, 3, 2, 3, 5, 2, 3], device='cuda:0'),
#   tensor([7, 4, 0, 5, 3, 1, 2, 3, 3, 1, 7, 0, 2, 2, 7], device='cuda:0'),
#   tensor([7, 0, 7, 8, 7, 0, 7, 5, 0, 6, 7, 6, 0, 8, 2], device='cuda:0'),
#   tensor([8, 0, 8, 8, 3, 4, 2, 1, 7, 5, 2, 6, 6, 7, 1], device='cuda:0'),
#   tensor([5, 6, 6, 0, 6, 1, 1, 5, 6, 1, 8, 8, 6, 1, 6], device='cuda:0'),
#   tensor([2, 7, 7, 4, 4, 7, 4, 3, 3, 5, 4, 6, 5, 6, 5], device='cuda:0'),
#   tensor([2, 7, 4, 2, 3, 7, 3, 3, 3, 2, 4, 7, 8, 7, 4], device='cuda:0'),
#   tensor([4, 7, 3, 2, 2, 7, 0, 6, 4, 7, 7, 2, 4, 5, 0], device='cuda:0'),
#   tensor([1, 3, 5, 4, 7, 3, 3, 4, 1, 5, 0, 6, 6, 7, 3], device='cuda:0'),
#   tensor([2, 7, 3, 7, 4, 8, 2, 8, 6, 2, 6, 4, 2, 2, 6], device='cuda:0'),
#   tensor([5, 3, 6, 3, 4, 5, 6, 1, 8, 7, 2, 7, 3, 7, 6], device='cuda:0'),
#   tensor([2, 1, 5, 1, 2, 8, 6, 0, 0, 8, 2, 8, 1, 3, 2], device='cuda:0'),
#   tensor([2, 5, 3, 4, 3, 5, 7, 1, 4, 8, 3, 4, 4, 2, 7], device='cuda:0'),
#   tensor([2, 7, 0, 4, 6, 6, 3, 8, 3, 2, 7, 3, 5, 7, 6], device='cuda:0'),
#   tensor([7, 8, 3, 1, 5, 2, 1, 1, 1, 7, 7, 7, 8, 5, 7], device='cuda:0'),
#   tensor([1, 7, 5, 7, 5, 6, 1, 5, 6, 1, 4, 5, 7, 5, 7], device='cuda:0'),
#   tensor([6, 8, 8, 4, 8, 4, 5, 2, 2, 6, 2, 3, 2, 7, 3], device='cuda:0'),
#   tensor([0, 8, 5, 0, 4, 1, 4, 6, 7, 3, 0, 2, 3, 2, 2], device='cuda:0'),
#   tensor([1, 5, 7, 5, 2, 6, 2, 3, 4, 5, 1, 3, 7, 8, 5], device='cuda:0'),
#   tensor([0, 3, 8, 8, 3, 8, 2, 3, 6, 7, 3, 1, 5, 7, 1], device='cuda:0'),
#   tensor([5, 0, 7, 3, 3, 3, 2, 0, 6, 7, 8, 2, 4, 2, 7], device='cuda:0'),
#   tensor([1, 4, 7, 0, 1, 4, 6, 1, 5, 5, 5, 1, 7, 2, 2], device='cuda:0'),
#   tensor([6, 4, 0, 5, 2, 5, 8, 8, 4, 0, 2, 0, 0, 7, 1], device='cuda:0'),
#   tensor([8, 5, 8, 3, 1, 2, 0, 5, 1, 3, 6, 6, 4, 6, 5], device='cuda:0'),
#   tensor([8, 7, 3, 1, 7, 5, 3, 7, 8, 3, 4, 4, 3, 0, 1], device='cuda:0'),
#   tensor([5, 7, 4, 0, 4, 8, 6, 5, 3, 3, 1, 5, 7, 6, 6], device='cuda:0'),
#   tensor([3, 3, 6, 4, 2, 0, 3, 4, 6, 8, 4, 0, 3, 3, 5], device='cuda:0'),
#   tensor([0, 1, 3, 0, 6, 2, 3, 5, 2, 6, 1, 5, 8, 5, 8], device='cuda:0'),
#   tensor([0, 5, 6, 8, 3, 3, 1, 1, 5, 4, 8, 4, 5, 1, 4], device='cuda:0'),
#   tensor([3, 5, 3, 2, 2, 3, 3, 5, 7, 4, 0, 7, 8, 4, 8], device='cuda:0'),
#   tensor([6, 4, 0, 4, 6, 4, 8, 0, 2, 5, 6, 6, 0, 5, 5], device='cuda:0'),
#   tensor([8, 3, 3, 4, 4, 4, 0, 6, 5, 1, 6, 5, 2, 4, 6], device='cuda:0'),
#   tensor([0, 4, 5, 3, 3, 5, 1, 2, 1, 8, 4, 1, 1, 4, 8], device='cuda:0'),
#   tensor([6, 7, 5, 0, 8, 1, 1, 6, 6, 8, 0, 0, 7, 1, 7], device='cuda:0'),
#   tensor([0, 1, 8, 5, 8, 3, 2, 8, 0, 4, 8, 1, 0, 4, 5], device='cuda:0'),
#   tensor([3, 8, 6, 4, 1, 4, 6, 6, 8, 5, 3, 6, 5, 1, 6], device='cuda:0'),
#   tensor([0, 7, 1, 5, 5, 5, 3, 6, 5, 7, 2, 4, 0, 5, 0], device='cuda:0'),
#   tensor([2, 0, 4, 0, 1, 4, 4, 4, 0, 0, 6, 3, 3, 8, 2], device='cuda:0'),
#   tensor([5, 0, 8, 6, 2, 7, 1, 4, 2, 8, 6, 5, 1, 0, 5], device='cuda:0'),
#   tensor([1, 1, 4, 4, 0, 0, 7, 5, 7, 0, 0, 5, 2, 0, 7], device='cuda:0'),
#   tensor([3, 5, 7, 1, 3, 3, 3, 8, 0, 3, 0, 8, 5, 6, 3], device='cuda:0'),
#   tensor([1, 5, 8, 7, 0, 6, 5, 2, 3, 3, 7, 8, 6, 0, 4], device='cuda:0'),
#   tensor([8, 7, 4, 3, 6, 4, 3, 0, 8, 4, 3, 1, 0, 5, 4], device='cuda:0'),
#   tensor([2, 2, 3, 8, 5, 4, 3, 6, 8, 1, 6, 2, 1, 8, 6], device='cuda:0'),
#   tensor([3, 3, 0, 3, 0, 6, 8, 7, 6, 1, 5, 1, 6, 8, 1], device='cuda:0'),
#   tensor([7, 3, 4, 3, 3, 6, 3, 6, 2, 4, 8, 1, 5, 0, 8], device='cuda:0'),
#   tensor([4, 0, 7, 3, 1, 2, 2, 5, 1, 6, 2, 6, 6, 6, 7], device='cuda:0'),
#   tensor([3, 8, 4, 2, 3, 8, 7, 8, 6, 1, 7, 8, 8, 8, 3], device='cuda:0'),
#   tensor([0, 7, 3, 5, 4, 0, 6, 3, 7, 0, 7, 3, 3, 8, 6], device='cuda:0'),
#   tensor([0, 8, 7, 6, 1, 5, 1, 8, 4, 5, 5, 6, 4, 0, 7], device='cuda:0'),
#   tensor([3, 1, 7, 4, 3, 2, 8, 2, 8, 5, 1, 1, 4, 1, 6], device='cuda:0'),
#   tensor([6, 6, 8, 3, 3, 7, 8, 1, 1, 0, 8, 7, 8, 1, 1], device='cuda:0'),
#   tensor([8, 2, 5, 5, 5, 2, 2, 5, 7, 7, 6, 6, 2, 0, 5], device='cuda:0'),
#   tensor([4, 5, 3, 3, 5, 4, 8, 6, 7, 3, 8, 0, 4, 7, 7], device='cuda:0'),
#   tensor([3, 1, 6, 1, 2, 6, 6, 2, 2, 0, 1, 1, 1, 4, 7], device='cuda:0'),
#   tensor([1, 7, 1, 1, 2, 7, 2, 6, 5, 0, 8, 0, 2, 6, 8], device='cuda:0'),
#   tensor([4, 5, 0, 6, 2, 8, 1, 7, 3, 4, 5, 0, 5, 7, 1], device='cuda:0'),
#   tensor([5, 3, 1, 8, 2, 8, 6, 2, 3, 1, 8, 6, 4, 5, 1], device='cuda:0'),
#   tensor([7, 5, 6, 1, 1, 6, 8, 3, 2, 4, 7, 2, 2, 2, 3], device='cuda:0'),
#   tensor([3, 3, 1, 7, 1, 0, 4, 1, 8, 1, 6, 6, 6, 6, 3], device='cuda:0'),
#   tensor([2, 1, 3, 7, 1, 6, 8, 4, 3, 7, 1, 1, 1, 8, 5], device='cuda:0'),
#   tensor([6, 4, 5, 0, 6, 6, 1, 7, 1, 1, 1, 5, 5, 1, 7], device='cuda:0'),
#   tensor([6, 6, 8, 8, 5, 2, 6, 1, 7, 4, 6, 6, 3, 8, 1], device='cuda:0'),
#   tensor([5, 7, 4, 2, 2, 2, 2, 4, 1, 5, 7, 4, 7, 5, 7], device='cuda:0'),
#   tensor([3, 7, 7, 7, 2, 1, 4, 3, 4, 6, 7, 4, 5, 1, 0], device='cuda:0'),
#   tensor([5, 5, 7, 1, 3, 7, 1, 5, 6, 0, 2, 6, 2, 3, 3], device='cuda:0'),
#   tensor([6, 8, 1, 6, 1, 6, 7, 5, 2, 7, 3, 7, 6, 5, 5], device='cuda:0'),
#   tensor([7, 1, 2, 3, 1, 1, 3, 8, 7, 6, 7, 1, 8, 5, 3], device='cuda:0'),
#   tensor([5, 2, 5, 7, 4, 5, 4, 6, 0, 2, 3, 2, 7, 7, 8], device='cuda:0'),
#   tensor([2, 6, 0, 6, 8, 6, 7, 7, 0, 7, 8, 3, 6, 0, 5], device='cuda:0'),
#   tensor([8, 2, 7, 4, 7, 1, 7, 5, 4, 6, 2, 0, 7, 7, 0], device='cuda:0'),
#   tensor([4, 0, 2, 5, 4, 8, 8, 7, 7, 7, 3, 6, 4, 6, 7], device='cuda:0'),
#   tensor([7, 7, 8, 7, 1, 0, 1, 2, 0, 5, 2, 8, 2, 0, 1], device='cuda:0'),
#   tensor([7, 7, 6, 7, 5, 6, 1, 4, 1, 2, 7, 7, 5, 7, 1], device='cuda:0'),
#   tensor([3, 6, 0, 1, 5, 8, 0, 6, 5, 0, 1, 6, 3, 3, 8], device='cuda:0'),
#   tensor([3, 7, 1, 7, 5, 5, 4, 1, 6, 2, 6, 7, 6, 8, 3], device='cuda:0'),
#   tensor([2, 6, 3, 0, 7, 3, 1, 5, 1, 7, 8, 7, 8, 2, 7], device='cuda:0'),
#   tensor([1, 6, 1, 1, 3, 8, 3, 3, 7, 0, 2, 2, 4, 4, 2], device='cuda:0'),
#   tensor([0, 3, 4, 1, 7, 5, 8, 4, 5, 5, 1, 2, 8, 5, 7], device='cuda:0'),
#   tensor([6, 0, 3, 4, 0, 6, 1, 2, 6, 0, 8, 4, 6, 2, 8], device='cuda:0'),
#   tensor([1, 7, 2, 6, 2, 7, 4, 2, 6, 6, 4, 5, 4, 6, 3], device='cuda:0'),
#   tensor([4, 5, 8, 0, 3, 1, 7, 7, 0, 6, 1, 2, 0, 7, 8], device='cuda:0'),
#   tensor([5, 3, 2, 1, 4, 0, 2, 1, 7, 0, 3, 4, 0, 1, 3], device='cuda:0'),
#   tensor([1, 8, 2, 0, 7, 8, 7, 8, 4, 3, 2, 2, 3, 0, 1], device='cuda:0'),
#   tensor([8, 0, 2, 1, 3, 5, 0, 5, 2, 5, 4, 3, 6, 8, 1], device='cuda:0'),
#   tensor([5, 1, 2, 2, 8, 2, 0, 6, 8, 1, 5, 1, 7, 7, 2], device='cuda:0'),
#   tensor([8, 4, 6, 6, 1, 7, 5, 8, 7, 1, 3, 5, 6, 1, 0], device='cuda:0'),
#   tensor([3, 8, 2, 6, 6, 6, 7, 1, 1, 0, 5, 0, 8, 2, 1], device='cuda:0'),
#   tensor([1, 6, 8, 8, 8, 4, 5, 8, 6, 7, 7, 4, 1, 3, 4], device='cuda:0'),
#   tensor([3, 4, 7, 5, 7, 8, 6, 1, 1, 2, 7, 2, 3, 1, 8], device='cuda:0'),
#   tensor([5, 1, 7, 8, 5, 0, 3, 8, 1, 7, 8, 4, 8, 1, 4], device='cuda:0'),
#   tensor([5, 2, 8, 3, 5, 6, 7, 6, 7, 1, 7, 1, 5, 8, 0], device='cuda:0'),
#   tensor([8, 7, 7, 7, 4, 4, 4, 3, 8, 4, 1, 3, 0, 0, 2], device='cuda:0'),
#   tensor([5, 7, 8, 1, 7, 0, 3, 2, 3, 4, 6, 6, 0, 0, 7], device='cuda:0'),
#   tensor([8, 6, 5, 1, 3, 7, 2, 5, 5, 5, 5, 7, 6, 8, 0], device='cuda:0'),
#   tensor([3, 1, 8, 0, 6, 1, 0, 6, 8, 0, 1, 0, 3, 2, 1], device='cuda:0'),
#   tensor([7, 6, 7, 7, 0, 3, 7, 0, 5, 5, 7, 1, 8, 2, 7], device='cuda:0'),
#   tensor([0, 3, 4, 6, 5, 2, 4, 8, 1, 4, 2, 5, 0, 4, 6], device='cuda:0'),
#   tensor([0, 4, 8, 1, 7, 0, 2, 8, 3, 6, 7, 5, 4, 1, 6], device='cuda:0'),
#   tensor([6, 6, 8, 8, 1, 1, 3, 7, 3, 4, 2, 1, 8, 4, 5], device='cuda:0'),
#   tensor([2, 0, 2, 2, 2, 7, 3, 5, 0, 1, 1, 3, 6, 4, 5], device='cuda:0'),
#   tensor([8, 6, 0, 4, 7, 2, 0, 3, 7, 1, 6, 7, 0, 3, 1], device='cuda:0'),
#   tensor([3, 5, 4, 7, 8, 5, 6, 2, 2, 8, 8, 4, 0, 2, 8], device='cuda:0'),
#   tensor([1, 6, 2, 5, 6, 3, 7, 8, 0, 8, 4, 5, 8, 0, 6], device='cuda:0'),
#   tensor([0, 3, 8, 7, 6, 3, 3, 4, 1, 7, 1, 7, 2, 6, 0], device='cuda:0'),
#   tensor([2, 7, 6, 1, 2, 0, 3, 0, 6, 2, 8, 6, 8, 2, 7], device='cuda:0'),
#   tensor([2, 5, 4, 1, 0, 8, 1, 6, 1, 6, 6, 4, 8, 2, 7], device='cuda:0'),
#   tensor([8, 6, 6, 7, 1, 5, 2, 4, 1, 1, 0, 6, 6, 8, 7], device='cuda:0'),
#   tensor([4, 1, 1, 4, 7, 0, 3, 8, 6, 1, 2, 5, 8, 1, 8], device='cuda:0'),
#   tensor([5, 4, 8, 2, 0, 4, 4, 3, 5, 4, 7, 6, 1, 8, 3], device='cuda:0'),
#   tensor([1, 2, 7, 8, 2, 3, 2, 1, 1, 4, 3, 2, 7, 7, 4], device='cuda:0'),
#   tensor([2, 2, 6, 4, 0, 2, 6, 8, 2, 2, 6, 4, 2, 1, 3], device='cuda:0'),
#   tensor([0, 2, 7, 1, 2, 7, 0, 4, 2, 2, 2, 4, 8, 6, 5], device='cuda:0'),
#   tensor([1, 7, 1, 8, 1, 0, 3, 7, 4, 7, 8, 0, 5, 5, 7], device='cuda:0'),
#   tensor([7, 7, 4, 4, 4, 4, 1, 0, 1, 0, 3, 4, 4, 1, 7], device='cuda:0'),
#   tensor([5, 3, 2, 2, 3, 2, 0, 6, 0, 8, 6, 7, 3, 7, 3], device='cuda:0'),
#   tensor([2, 4, 3, 1, 5, 7, 4, 1, 7, 4, 3, 5, 7, 0, 8], device='cuda:0'),
#   tensor([4, 5, 0, 5, 1, 4, 1, 4, 8, 0, 6, 3, 0, 0, 0], device='cuda:0'),
#   tensor([1, 4, 3, 4, 8, 5, 7, 5, 7, 0, 7, 1, 5, 2, 7], device='cuda:0'),
#   tensor([2, 0, 8, 6, 8, 0, 1, 5, 7, 3, 8, 8, 4, 0, 1], device='cuda:0'),
#   tensor([0, 6, 5, 5, 2, 7, 0, 4, 1, 3, 3, 5, 5, 1, 8], device='cuda:0'),
#   tensor([3, 5, 6, 0, 1, 8, 7, 3, 1, 2, 6, 4, 1, 4, 0], device='cuda:0'),
#   tensor([3, 7, 2, 0, 7, 5, 5, 5, 3, 5, 4, 5, 4, 4, 5], device='cuda:0'),
#   tensor([0, 6, 3, 1, 1, 5, 1, 5, 4, 7, 1, 5, 8, 0, 7], device='cuda:0'),
#   tensor([0, 3, 1, 4, 1, 1, 3, 4, 6, 1, 5, 6, 1, 1, 1], device='cuda:0'),
#   tensor([0, 6, 1, 3, 0, 5, 4, 1, 4, 1, 4, 6, 5, 3, 3], device='cuda:0'),
#   tensor([4, 5, 6, 8, 4, 6, 7, 6, 4, 0, 6, 3, 1, 7, 6], device='cuda:0'),
#   tensor([4, 1, 3, 4, 4, 6, 2, 1, 5, 1, 0, 5, 1, 1, 6], device='cuda:0'),
#   tensor([0, 1, 4, 2, 3, 2, 1, 0, 5, 4, 4, 2, 2, 0, 0], device='cuda:0'),
#   tensor([7, 1, 2, 1, 2, 6, 5, 6, 1, 2, 6, 7, 0, 8, 5], device='cuda:0'),
#   tensor([0, 4, 2, 2, 8, 3, 5, 8, 1, 2, 1, 1, 1, 0, 4], device='cuda:0'),
#   tensor([1, 1, 6, 4, 8, 1, 8, 4, 1, 1, 2, 7, 1, 6, 3], device='cuda:0'),
#   tensor([1, 5, 1, 6, 1, 2, 3, 5, 2, 4, 1, 5, 6, 1, 6], device='cuda:0'),
#   tensor([4, 2, 2, 7, 7, 4, 8, 3, 5, 7, 5, 6, 3, 5, 0], device='cuda:0'),
#   tensor([7, 7, 2, 0, 3, 8, 3, 1, 6, 4, 5, 7, 3, 8, 0], device='cuda:0'),
#   tensor([2, 3, 4, 3, 6, 3, 3, 0, 8, 6, 8, 2, 2, 0, 8], device='cuda:0'),
#   tensor([4, 1, 6, 6, 8, 6, 7, 6, 1, 6, 7, 5, 5, 8, 7], device='cuda:0'),
#   tensor([7, 2, 2, 5, 0, 7, 5, 5, 6, 6, 3, 5, 3, 0, 5], device='cuda:0'),
#   tensor([8, 8, 5, 3, 1, 8, 1, 0, 0, 2, 1, 0, 0, 5, 1], device='cuda:0'),
#   tensor([4, 5, 3, 0, 3, 3, 1, 1, 4, 8, 2, 4, 4, 7, 0], device='cuda:0'),
#   tensor([4, 0, 4, 0, 6, 5, 3, 4, 1, 3, 6, 5, 7, 1, 5], device='cuda:0'),
#   tensor([0, 3, 5, 1, 0, 6, 1, 1, 0, 2, 7, 3, 1, 4, 6], device='cuda:0'),
#   tensor([1, 1, 6, 1, 2, 7, 5, 8, 0, 7, 2, 4, 8, 1, 0], device='cuda:0'),
#   tensor([0, 5, 5, 4, 6, 1, 2, 6, 2, 3, 3, 5, 6, 1, 6], device='cuda:0'),
#   tensor([5, 4, 4, 8, 7, 4, 5, 1, 7, 6, 3, 8, 0, 1, 6], device='cuda:0'),
#   tensor([0, 2, 6, 5, 5, 6, 6, 1, 4, 5, 1, 6, 1, 7, 0], device='cuda:0'),
#   tensor([8, 7, 4, 7, 0, 5, 4, 8, 5, 8, 5, 6, 8, 1, 7], device='cuda:0'),
#   tensor([7, 3, 6, 0, 2, 6, 4, 4, 3, 0, 8, 7, 5, 5, 8], device='cuda:0'),
#   tensor([5, 2, 5, 2, 0, 3, 6, 2, 4, 6, 4, 4, 1, 8, 2], device='cuda:0'),
#   tensor([4, 5, 5, 0, 5, 3, 4, 6, 2, 8, 3, 6, 5, 4, 4], device='cuda:0'),
#   tensor([3, 3, 2, 5, 3, 1, 1, 8, 6, 7, 4, 2, 7, 0, 7], device='cuda:0'),
#   tensor([3, 6, 1, 1, 7, 5, 0, 8, 7, 1, 5, 1, 2, 0, 4], device='cuda:0'),
#   tensor([8, 5, 3, 1, 2, 5, 1, 1, 3, 0, 8, 3, 0, 5, 5], device='cuda:0'),
#   tensor([7, 7, 5, 4, 6, 8, 2, 4, 3, 6, 7, 0, 1, 3, 5], device='cuda:0'),
#   tensor([8, 4, 2, 4, 5, 7, 4, 6, 3, 8, 6, 0, 7, 2, 4], device='cuda:0'),
#   tensor([2, 7, 7, 0, 7, 8, 4, 7, 8, 6, 6, 0, 7, 8, 1], device='cuda:0'),
#   tensor([6, 0, 1, 6, 8, 6, 7, 5, 4, 1, 3, 6, 4, 2, 6], device='cuda:0'),
#   tensor([3, 5, 6, 3, 2, 1, 4, 7, 5, 8, 5, 4, 3, 6, 7], device='cuda:0'),
#   tensor([1, 6, 8, 1, 4, 5, 3, 4, 4, 8, 3, 1, 1, 2, 4], device='cuda:0'),
#   tensor([8, 4, 7, 4, 1, 6, 1, 2, 8, 2, 5, 7, 6, 1, 3], device='cuda:0'),
#   tensor([8, 6, 8, 5, 1, 6, 7, 7, 7, 1, 0, 6, 2, 6, 4], device='cuda:0'),
#   tensor([5, 6, 0, 5, 5, 1, 1, 6, 3, 3, 5, 4, 6, 0, 4], device='cuda:0'),
#   tensor([4, 4, 8, 2, 1, 3, 2, 5, 5, 3, 8, 1, 2, 1, 5], device='cuda:0'),
#   tensor([0, 1, 3, 8, 4, 2, 0, 4, 6, 2, 0, 2, 5, 0, 0], device='cuda:0'),
#   tensor([5, 0, 1, 6, 2, 6, 4, 2, 1, 7, 4, 6, 7, 8, 0], device='cuda:0'),
#   tensor([5, 6, 8, 1, 8, 6, 7, 1, 2, 4, 6, 0, 3, 8, 7], device='cuda:0'),
#   tensor([5, 0, 0, 0, 2, 0, 2, 6, 2, 2, 4, 1, 7, 2, 7], device='cuda:0'),
#   tensor([4, 3, 1, 1, 5, 2, 0, 1, 1, 8, 8, 7, 3, 7, 4], device='cuda:0'),
#   tensor([0, 2, 7, 0, 1, 8, 7, 7, 1, 7, 5, 3, 4, 8, 0], device='cuda:0'),
#   tensor([2, 3, 6, 0, 4, 1, 8, 2, 8, 1, 1, 6, 6, 8, 6], device='cuda:0'),
#   tensor([2, 4, 0, 4, 0, 0, 5, 3, 0, 5, 3, 0, 4, 6, 8], device='cuda:0'),
#   tensor([5, 1, 5, 8, 2, 3, 1, 3, 6, 7, 8, 6, 3, 5, 1], device='cuda:0'),
#   tensor([7, 5, 8, 1, 2, 7, 8, 2, 5, 0, 1, 1, 3, 2, 8], device='cuda:0'),
#   tensor([3, 8, 8, 1, 2, 0, 6, 4, 6, 7, 5, 4, 2, 0, 4], device='cuda:0'),
#   tensor([3, 1, 5, 0, 7, 6, 7, 7, 6, 8, 8, 8, 6, 8, 1], device='cuda:0'),
#   tensor([5, 7, 6, 3, 6, 0, 6, 4, 1, 8, 5, 4, 1, 1, 1], device='cuda:0'),
#   tensor([8, 8, 1, 6, 2, 0, 1, 6, 4, 2, 0, 4, 8, 6, 1], device='cuda:0'),
#   tensor([4, 5, 6, 0, 6, 7, 1, 7, 4, 3, 7, 0, 5, 8, 2], device='cuda:0'),
#   tensor([2, 2, 4, 4, 6, 2, 4, 0, 8, 5, 3, 8, 0, 3, 6], device='cuda:0'),
#   tensor([0, 6, 0, 4, 7, 4, 6, 7, 5, 6, 2, 5, 8, 1, 0], device='cuda:0'),
#   tensor([6, 3, 1, 7, 4, 8, 4, 2, 8, 4, 3, 7, 0, 6, 7], device='cuda:0'),
#   tensor([4, 8, 5, 5, 5, 4, 2, 5, 6, 8, 6, 1, 7, 2, 1], device='cuda:0'),
#   tensor([4, 0, 0, 5, 8, 8, 0, 2, 3, 2, 1, 3, 2, 8, 6], device='cuda:0'),
#   tensor([4, 7, 8, 5, 2, 4, 0, 6, 1, 4, 1, 4, 7, 8, 8], device='cuda:0'),
#   tensor([3, 7, 1, 2, 2, 5, 6, 6, 8, 7, 4, 6, 2, 4, 5], device='cuda:0'),
#   tensor([0, 2, 2, 0, 5, 0, 2, 1, 4, 0, 3, 5, 4, 8, 4], device='cuda:0'),
#   tensor([3, 1, 1, 5, 3, 0, 2, 1, 0, 7, 0, 6, 0, 5, 4], device='cuda:0'),
#   tensor([2, 5, 5, 6, 8, 2, 4, 2, 6, 8, 5, 4, 7, 7, 8], device='cuda:0'),
#   tensor([4, 4, 7, 8, 2, 4, 1, 2, 6, 7, 1, 6, 4, 2, 6], device='cuda:0'),
#   tensor([7, 2, 5, 6, 7, 7, 2, 3, 5, 2, 4, 1, 3, 0, 1], device='cuda:0'),
#   tensor([1, 0, 8, 7, 7, 6, 1, 0, 8, 0, 1, 1, 2, 2, 1], device='cuda:0'),
#   tensor([5, 8, 5, 6, 5, 0, 0, 2, 8, 3, 3, 0, 5, 0, 2], device='cuda:0'),
#   tensor([1, 1, 1, 6, 8, 8, 2, 2, 8, 4, 6, 4, 5, 2, 2], device='cuda:0'),
#   tensor([0, 6, 5, 5, 3, 0, 2, 6, 7, 4, 1, 7, 5, 6, 8], device='cuda:0'),
#   tensor([0, 5, 3, 7, 6, 0, 7, 0, 8, 4, 5, 6, 8, 6, 1], device='cuda:0'),
#   tensor([2, 2, 8, 4, 6, 4, 7, 7, 5, 4, 8, 8, 8, 1, 5], device='cuda:0'),
#   ...],
#  tensor([[ 0.2989,  0.0601, -0.0978,  ..., -0.0304, -0.0535, -0.0792],
#          [ 0.3403,  0.0731, -0.1222,  ..., -0.0490, -0.0470, -0.0518],
#          [ 0.3621,  0.0747, -0.1625,  ..., -0.0592, -0.0285, -0.0748],
#          ...,
#          [ 0.3055,  0.0498, -0.1237,  ..., -0.0298, -0.0734, -0.0888],
#          [ 0.4009,  0.0113, -0.1158,  ..., -0.0440, -0.0197, -0.0460],
#          [ 0.3721,  0.0289, -0.1218,  ..., -0.0267, -0.0625, -0.0428]]))

# %% [markdown]
# vis

# %%
def save_matrix(matrix, fpath):
    D1, D2 = matrix.shape
    tsv = ""
    for i in range(D1):
        for j in range(D2):
            tsv += str(matrix.iloc[i, j]) + '\t'
        tsv = tsv.strip('\t') + '\n'
    tsv = tsv.strip('\n')
    with open(fpath, "w") as fd:
        fd.write(tsv)

preds_list, embeddings_vectors= runner(test_batches, 'test', train=False)
embeddings_vect= embeddings_vectors.tolist()
embs_df= pd.DataFrame(embeddings_vect)
save_matrix(embs_df, "test_embeddings.tsv")
save_matrix(Xtest, "Xtest.tsv")
# Out:
# epoch: 1, test loss: 0.68415, f1-score: 0.78636, accuracy: 0.78646, precision: 0.78738, recall: 0.78632: 100%|██████████| 599/599 [00:25<00:00, 23.73it/s]

# %% [markdown]
# https://projector.tensorflow.org/

# %% [markdown]
# ## Part 8: LSTM

# %%
import tensorflow as tf
from tensorflow.keras import layers
from keras.layers import Dropout
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import string
from tensorflow.keras import utils
n_most_common_words = 8000
tokenizer = Tokenizer(num_words=n_most_common_words, filters=string.punctuation, lower=True)
def convert(txt):
  txt_=[str (item) for item in txt.tolist()]
  tokenizer.fit_on_texts(txt_)
  sequences = tokenizer.texts_to_sequences(txt_)
  X = pad_sequences(sequences)
  return X

Xdata=convert(News_DF['headline'])
Xtrain,Xtest ,ytrain,ytest = train_test_split(Xdata, News_DF['cata'], random_state = 2020, test_size = 0.2)
ytrain= utils.to_categorical(ytrain, 9)
ytest= utils.to_categorical(ytest, 9)

# %%
# no of Epochs for Model Training
epochs = 12
# Output Dimensions for Embedded Layer
emb_dim = 256
# Batch size for training
batch_size = 256
# Creating a LSTM model
model = tf.keras.Sequential()
model.add(layers.Embedding(n_most_common_words, emb_dim, input_length=Xtrain.shape[1]))
model.add(layers.LSTM(512, activation='sigmoid'))
model.add(layers.Dense(128,activation='relu'))
model.add(Dropout(0.4))
model.add(layers.Dense(9,activation='sigmoid'))
# compiling the layer 
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
print(model.summary())
# Training the model 
lstm = model.fit(Xtrain, ytrain, epochs=epochs, batch_size=batch_size, validation_split=0.1,callbacks=[tf.keras.callbacks.EarlyStopping(monitor='val_loss',patience=7, min_delta=0.0001)])
# Out:
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_2 (Embedding)     (None, 66, 256)           2048000
#
#  lstm_2 (LSTM)               (None, 512)               1574912
#
#  dense_4 (Dense)             (None, 128)               65664
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_5 (Dense)             (None, 9)                 1161
#
# =================================================================
# Total params: 3,689,737
# Trainable params: 3,689,737
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/12
# 127/127 [==============================] - 37s 277ms/step - loss: 2.1250 - accuracy: 0.1541 - val_loss: 1.8879 - val_accuracy: 0.2043
# Epoch 2/12
# 127/127 [==============================] - 34s 267ms/step - loss: 1.8029 - accuracy: 0.2553 - val_loss: 1.6536 - val_accuracy: 0.3476
# Epoch 3/12
# 127/127 [==============================] - 34s 269ms/step - loss: 1.4822 - accuracy: 0.4033 - val_loss: 1.3496 - val_accuracy: 0.4612
# Epoch 4/12
# 127/127 [==============================] - 34s 267ms/step - loss: 1.2045 - accuracy: 0.5326 - val_loss: 1.2504 - val_accuracy: 0.5477
# Epoch 5/12
# 127/127 [==============================] - 34s 266ms/step - loss: 1.0378 - accuracy: 0.6169 - val_loss: 1.1414 - val_accuracy: 0.6104
# Epoch 6/12
# 127/127 [==============================] - 34s 267ms/step - loss: 0.8863 - accuracy: 0.6928 - val_loss: 1.0795 - val_accuracy: 0.6476
# Epoch 7/12
# 127/127 [==============================] - 34s 271ms/step - loss: 0.7682 - accuracy: 0.7489 - val_loss: 1.0687 - val_accuracy: 0.6797
# Epoch 8/12
# 127/127 [==============================] - 34s 268ms/step - loss: 0.6756 - accuracy: 0.7831 - val_loss: 1.0339 - val_accuracy: 0.6991
# Epoch 9/12
# 127/127 [==============================] - 34s 265ms/step - loss: 0.5991 - accuracy: 0.8134 - val_loss: 1.0425 - val_accuracy: 0.7011
# Epoch 10/12
# 127/127 [==============================] - 34s 269ms/step - loss: 0.5436 - accuracy: 0.8340 - val_loss: 1.0472 - val_accuracy: 0.7225
# Epoch 11/12
# 127/127 [==============================] - 35s 274ms/step - loss: 0.4867 - accuracy: 0.8537 - val_loss: 1.0756 - val_accuracy: 0.7214
# Epoch 12/12
# 127/127 [==============================] - 34s 268ms/step - loss: 0.4278 - accuracy: 0.8728 - val_loss: 1.0589 - val_accuracy: 0.7234

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
ypred= model.predict(Xtest)
#score = model.evaluate(Xtest,ytest, batch_size=batch_size, verbose=0)
ypred= np.argmax(ypred, axis=1)
ytest=np.argmax(ytest, axis=1)
accuracy = accuracy_score(ytest, ypred)
precision = precision_score(ytest, ypred,average="micro")
recall = recall_score(ytest, ypred,average="micro")
f1 = f1_score(ytest, ypred,average="micro")
print("acc:{}, pre:{}, recall:{}, f1:{}".format(accuracy,precision,recall,f1))
# Out:
# acc:0.7189935426408373, pre:0.7189935426408373, recall:0.7189935426408373, f1:0.7189935426408373
